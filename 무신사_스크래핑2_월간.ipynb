# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import time
from tqdm import tqdm
import warnings
warnings.filterwarnings(action='ignore')

# %%
url="https://www.musinsa.com/ranking/best?period=month&age=ALL&mainCategory=001&subCategory=&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax="

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 pd.read_html(url)
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:939, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     937 else:
#     938     assert retained is not None  # for mypy
# --> 939     raise retained
#     941 ret = []
#     942 for table in tables:
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:569, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     566 tables = doc.find_all(element_name, attrs=attrs)
#     568 if not tables:
# --> 569     raise ValueError("No tables found")
#     571 result = []
#     572 unique_tables = set()
#
# ValueError: No tables found

# %%
#200 수신양호
response=requests.get(url)
response.status_code
# Out:
# 200

# %%
#순위에 맞춰 브랜드 이름 가져오기
#옷의 이름을 가져오기
#옷 링크 가져오기

html=bs(response.text, 'lxml')
html
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title>상품 랭킹 | 무신사 스토어</title>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.
# 무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다." name="description"/>
# <script type="text/javascript">
#             var THIS_PAGE_GF = 'A';
#         </script>
# <link href="https://image.msscdn.net/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="648837775133366" id="fbAddId" property="fb:app_id"/>
# <meta content="website" id="fbOgType" property="og:type"/>
# <meta content="상품 랭킹 | 무신사 스토어" id="fbOgTitle" property="og:title"/>
# <meta content="https://image.msscdn.net/mfile_s01/fb/share_musinsa.png" id="fbOgImage" property="og:image"/>
# <meta content="무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.
# 무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다." id="fbOgDescription" property="og:description"/>
# <meta content="https://www.musinsa.com/ranking/best?period=month&amp;age=ALL&amp;mainCategory=001&amp;subCategory=&amp;leafCategory=&amp;price=&amp;golf=false&amp;kids=false&amp;newProduct=false&amp;exclusive=false&amp;discount=false&amp;soldOut=false&amp;page=1&amp;viewType=small&amp;priceMin=&amp;priceMax=&amp;_gf=A" id="fbOgUrl" property="og:url"/>
# <link href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/store_common.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/style.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/sub.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/media_query.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/new.css?202302272038" rel="stylesheet" type="text/css"/>
# <!-- 검색페이지에서 사용 -->
# <!-- Swiper -->
# <link href="//static.msscdn.net/swiper/swiper.min.css" rel="stylesheet" type="text/css"/>
# <!--jqModal-->
# <link href="//static.msscdn.net/skin/musinsa/css/jqModal.css?202302272038" rel="stylesheet" type="text/css"/>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/skin/musinsa/css/image_search.css?202302272038" rel="stylesheet" type="text/css"/>
# <!-- //유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/static/common/1.2.0/pc.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/mfile_scr/layouts/community/css/musinsa_timeline.css?version=6.249" rel="stylesheet" type="text/css"/>
# <!-- 공통 레이아웃에서 사용함 -->
# <link href="//static.msscdn.net/ui/build/pc/css/common.css" rel="stylesheet" type="text/css"/>
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/base.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/common.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?202302272038" type="text/javascript"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/layout/common.js" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/ui.js?202302272038" type="text/javascript"></script>
# <!-- Swiper -->
# <script src="//static.msscdn.net/swiper/swiper.min.js"></script>
# <!--jqModal-->
# <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?202302272038" type="text/javascript"></script>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/search/image_search.js" type="text/javascript"></script>
# <script type="text/javascript">
#         $(document).ready(function(){
#             if (window.image_search) {
#                 window.image_search.setUrl('https://www.musinsa.com');
#             }
#         });
#     </script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/common/1.2.0/chunk-vendors.js"></script>
# <script href="//static.msscdn.net/layouts/community/js/musinsa_timeline.new.js?version=6.249" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/lib/blackhole/1.1.0/mssBlackholeSdk.js?202302272038"></script>
# <script>
#         var dataLayer = dataLayer || [];
#         dataLayer.push({
#             "productList" : {
#                 "email": "",
#                 // 조회 결과 중 상위 3개를 셋팅함. (goods_no-goods_sub)
#                 "list": []
#             }
#         });
#     </script>
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/layout/config.js" type="text/javascript"></script>
# <script>
#         var uiConfig = {
#             service : 'mensinsa',
#             isWusinsaService : false,
#             htmlTitle : '상품 랭킹 | 무신사 스토어',
#             isLoginYn: 'N',
#             memberGroupNo: '0',
#             total: '',
#             siteCode: 'mensinsa',
#             headerSex: '',
#             globalFilter: 'A',
#             globalFilterWrapperCssName: 'musinsa',
#
#             searchFrontServiceUrl: 'https://www.musinsa.com/search/musinsa/',
#             searchFrontUrl: 'https://www.musinsa.com',
#             searchApiUrl: 'https://search.musinsa.com',
#             serviceUrl : 'https://www.musinsa.com',
#             magazineUrl : 'https://magazine.musinsa.com',
#             storeUrl: 'https://www.musinsa.com',
#             mobileStoreUrl: 'https://www.musinsa.com',
#             wusinsaUrl : 'https://wusinsa.musinsa.com',
#             myPageFrontUrl: 'https://www.musinsa.com',
#
#             likeApiUrl : 'https://like.musinsa.com/like',
#             goodsDetailUrl: '/app/goods/',
#             brandShopUrl: 'https://www.musinsa.com/brands/',
#
#             cssResourceUrl : '//static.msscdn.net',
#             httpImageResourceUrl : 'https://image.msscdn.net',
#             imageResourceUrl : 'https://image.msscdn.net',
#             staticResourceUrl : '//static.msscdn.net',
#             staticResourceVersion : '202302272038',
#
#             noImagePrefix: 'no_image_'
#         };
#
#         mss.ui.config.set(uiConfig);
#
#     </script>
# <!-- mss.ui : global config end -->
# <!-- mss.ui : gnb start -->
# <script src="//static.msscdn.net/static/search/202302272038/js/ajax.js" type="text/javascript"></script>
# </head>
# <body>
# <script>
#         var siteCode = "mensinsa";
#
#         mss.ui.left = {
#             category: {
#                 dCatCd: "", // 선택된 카테고리 코드
#             },
#             menuType: 'list'
#         };
#
#         mss.ui.loggedIn = mss.ui.config.get().isLoginYn === 'Y';
#
#     </script>
# <div id="topCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/pc.js"></script>
# <div class="wrap">
# <div id="leftCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/lnb.js?202302272038"></script>
# <div class="right_area page-contents-best">
# <input name="d_cat_cd" type="hidden" value=""/>
# <div class="pagenation">
# <div class="nav_sub">
# <a href="https://www.musinsa.com">무신사 스토어</a>
# <span class="icon_entity">&gt;</span>
# <span>상품 랭킹</span>
# </div>
# <span class="txt_selected_division">all</span>
# </div>
# <div class="page_box">
# <div class="title_box">
# <h2 class="title-page">Ranking Shop</h2>
# <div class="tool-tabBtn">
# <a class="plain-btn btn active" href="https://www.musinsa.com/app/contents/bestranking">
#                                 상품
#                             </a><a class="plain-btn btn" href="https://www.musinsa.com/app/usr/brand_rank">
#                                 브랜드
#                             </a><a class="plain-btn btn" href="https://www.musinsa.com/app/usr/search_ranking">
#                                 검색어
#                             </a>
# </div>
# </div>
# <div class="page_intro">무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.<br/>무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다.</div>
# </div>
# <div class="n-banner-ranking">
# <a href="https://www.musinsa.com/app/cs/faq?q=%EB%9E%AD%ED%82%B9">
#                         무신사 랭킹을 알려드립니다.
#                         <em>
#                             자세히 보기
#                         </em>
# </a>
# </div>
# <form id="goodsRankForm">
# <div class="clear">
# <input name="period" type="hidden" value="month"/>
# <input name="age" type="hidden" value="ALL"/>
# <input name="mainCategory" type="hidden" value="001"/>
# <input name="subCategory" type="hidden" value=""/>
# <input name="leafCategory" type="hidden" value=""/>
# <input name="price" type="hidden" value=""/>
# <input name="golf" type="hidden" value="false"/>
# <input name="kids" type="hidden" value="false"/>
# <input name="newProduct" type="hidden" value="false"/>
# <input name="exclusive" type="hidden" value="false"/>
# <input name="discount" type="hidden" value="false"/>
# <input name="soldOut" type="hidden" value="false"/>
# <input name="page" type="hidden" value="1"/>
# <input name="viewType" type="hidden" value="small"/>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             기간 구분
#         </p>
# <dl class="list_division_brand">
# <dt></dt>
# <dd>
# <ul class="division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('now');">실시간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('day');">일간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('week');">주간</a>
# </li>
# <li class="selected">
# <a href="javascript:mss.ranking.goods.filter.period('month');">월간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('month_3');">3개월</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             대분류
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div>
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_reset">
# <li class="selected">
# <a href="javascript:mss.ranking.goods.filter.mainCategory('001');">상의</a>
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
# <span class="delete-btn-red">
#                                 X
#                             </span>
# </a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('002');">아우터</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('003');">바지</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('020');">원피스</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('022');">스커트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('018');">스니커즈</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('005');">신발</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('004');">가방</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('054');">여성 가방</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('017');">스포츠/용품</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('007');">모자</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('008');">양말/레그웨어</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('026');">속옷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('009');">선글라스/안경테</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('011');">액세서리</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('006');">시계</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('025');">주얼리</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('015');">뷰티</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('012');">디지털/테크</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('058');">리빙</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('014');">컬처</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('021');">반려동물</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             중분류
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div class="selected">
# <a href="javascript:mss.ranking.goods.filter.subCategory(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001006');">니트/스웨터</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001004');">후드 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001005');">맨투맨/스웨트셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001010');">긴소매 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001002');">셔츠/블라우스</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001003');">피케/카라 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001001');">반소매 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001011');">민소매 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001008');">기타 상의</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_price box_division_group">
# <p class="article_title">
#             가격
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div class="selected">
# <a href="javascript:mss.ranking.goods.filter.price(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_price division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('~50000');">5만원 이하</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('50000~100000');">5~10만원</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('100000~200000');">10~20만원</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('200000~300000');">20~30만원</a>
# </li>
# <li class="last">
# <a href="javascript:mss.ranking.goods.filter.price('300000~');">30만원 이상</a>
# </li>
# <li class="division_search_box search_price">
# <input class="division_search_input" maxlength="9" name="priceMin" title="최소 가격 검색" type="text" value=""/><span>원 ~</span>
# <input class="division_search_input" maxlength="9" name="priceMax" title="최대 가격 검색" type="text" value=""/><span>원</span>
# <span class="division_search_btn" onclick="mss.ranking.goods.filter.customPrice();">검색</span>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# </div>
# <div class="right_contents hover_box">
# <div class="select_option">
# <span class="keyword_selected">
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
#             대분류 : 상의
#             <span class="delete-btn-red">X</span>
# </a>
# </span>
# </div>
# <div class="boxed-list-wrapper rank-shop">
# <div class="sorter-box box">
# <p class="box_renew">
#                         7시간 전 갱신
#                     </p>
# <div class="pagination">
# <div class="wrapper">
# <a class="fa fa-angle-double-left paging-btn btn first" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">첫 페이지</label>
# </a>
# <a class="fa fa-angle-left paging-btn btn prev" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">이전</label>
# </a>
# <a class="paging-btn btn active" href="javascript:mss.ranking.goods.page(1);">1</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(2);">2</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(3);">3</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(4);">4</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(5);">5</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(6);">6</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(7);">7</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(8);">8</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(9);">9</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(10);">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:mss.ranking.goods.page(11);">
# <label style="display:none">다음</label>
# </a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:mss.ranking.goods.page(100);">
# <label style="display:none">마지막 페이지</label>
# </a>
# </div>
# </div>
# </div>
# <div class="thumbType_box box">
# <span class="image_view_select">
# <a class="view_select_small selected" href="javascript:mss.ranking.goods.viewType('small');" title="작은 이미지">
#                             작은 이미지
#                         </a>
# <a class="view_select_big" href="javascript:mss.ranking.goods.viewType('large');" title="큰 이미지">
#                             큰 이미지
#                         </a>
# </span>
# <span class="counter check_box_area">
# <label><input alt="요즘 신상" autocomplete="off" onchange="mss.ranking.goods.filter.check('newProduct', this.checked);" type="checkbox" value="false"/>🔥 NEW</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('exclusive', this.checked);" type="checkbox" value="false"/>단독</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('discount', this.checked);" type="checkbox" value="false"/>세일</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('soldOut', this.checked);" type="checkbox" value="false"/>품절 포함</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('golf', this.checked);" type="checkbox" value="false"/>골프</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('kids', this.checked);" type="checkbox" value="false"/>키즈</label>
# </span>
# <span class="counter box_num_goods">
# <label class="is_goods">상품 수 : 172,015개</label>
# </span>
# <span class="pagingNumber">
# <span class="totalPagingNum">100</span>
#         페이지 중
#         <span class="currentPagingNum">1</span>
#         페이지
#
# </span>
# </div>
# <div class="list-box box">
# <ul class="snap-article-list boxed-article-list article-list center list goods_small_media8" id="goodsRankList">
# <li class="li_box" data-goods-no="2396645">
# <p class="n-label label-default txt_num_rank">
#             1위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2396645?loc=goods_rank">
# <img alt="수아레(SUARE) 워셔블 하찌 니트 - 11 COLOR" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220303/2396645/2396645_4_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/suare">수아레</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2396645?loc=goods_rank" title="워셔블 하찌 니트 - 11 COLOR">
#
#
#
#
#                         워셔블 하찌 니트 - 11 COLOR
#                     </a>
# </p>
# <p class="price">
# <del>59,000원</del>
#                     39,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2396645', '2396645', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2396645" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2396645', '2396645', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">39,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">22,408</span>
# </p>
# <p class="txt_cnt_like goods_like_2396645 hide" id="like_2396645">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2396645" onclick="viewOption3(this, '2396645', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2396645" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2086653">
# <p class="n-label label-default txt_num_rank">
#             2위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2086653?loc=goods_rank">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210825/2086653/2086653_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/musinsastandard">무신사 스탠다드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2086653?loc=goods_rank" title="레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]">
#
#
#
#
#                         레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]
#                     </a>
# </p>
# <p class="price">
#
#                     16,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2086653', '2086653', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2086653" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2086653', '2086653', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">16,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">37,638</span>
# </p>
# <p class="txt_cnt_like goods_like_2086653 hide" id="like_2086653">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2086653" onclick="viewOption3(this, '2086653', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2086653" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2272830">
# <p class="n-label label-default txt_num_rank">
#             3위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2272830?loc=goods_rank">
# <img alt="스파오(SPAO) (시티보이) 오버핏 옥스포드 셔츠_SPYWD23C01" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20211220/2272830/2272830_16765946783470_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/spao">스파오</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2272830?loc=goods_rank" title="(시티보이) 오버핏 옥스포드 셔츠_SPYWD23C01">
#
#
#
#
#                         (시티보이) 오버핏 옥스포드 셔츠_SPYWD23C01
#                     </a>
# </p>
# <p class="price">
# <del>39,900원</del>
#                     35,910원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-3,591원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2272830', '2272830', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2272830" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2272830', '2272830', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">35,910원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">17,488</span>
# </p>
# <p class="txt_cnt_like goods_like_2272830 hide" id="like_2272830">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2272830" onclick="viewOption3(this, '2272830', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2272830" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2326935">
# <p class="n-label label-default txt_num_rank">
#             4위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2326935?loc=goods_rank">
# <img alt="예일(YALE) (23SS) 2 TONE ARCH HOODIE GRAY" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220125/2326935/2326935_11_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/yale">예일</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2326935?loc=goods_rank" title="(23SS) 2 TONE ARCH HOODIE GRAY">
#
#
#
#
#                         (23SS) 2 TONE ARCH HOODIE GRAY
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     55,300원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-5,530원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2326935', '2326935', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2326935" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2326935', '2326935', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">55,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">12,567</span>
# </p>
# <p class="txt_cnt_like goods_like_2326935 hide" id="like_2326935">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2326935" onclick="viewOption3(this, '2326935', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2326935" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2314616">
# <p class="n-label label-default txt_num_rank">
#             5위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2314616?loc=goods_rank">
# <img alt="토피(TOFFEE) 에센셜 후드 스웻 셔츠 (MELANGE GREY)" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220119/2314616/2314616_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/toffee">토피</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2314616?loc=goods_rank" title="에센셜 후드 스웻 셔츠 (MELANGE GREY)">
#
#
#
#
#                         에센셜 후드 스웻 셔츠 (MELANGE GREY)
#                     </a>
# </p>
# <p class="price">
# <del>43,000원</del>
#                     37,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2314616', '2314616', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2314616" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2314616', '2314616', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">37,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">7,708</span>
# </p>
# <p class="txt_cnt_like goods_like_2314616 hide" id="like_2314616">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2314616" onclick="viewOption3(this, '2314616', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2314616" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1582356">
# <p class="n-label label-default txt_num_rank">
#             6위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1582356?loc=goods_rank">
# <img alt="소버먼트(SOVERMENT) 980g pigment mtm-charcoal-" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200903/1582356/1582356_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/sovermentwithlomort">소버먼트</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1582356?loc=goods_rank" title="980g pigment mtm-charcoal-">
#
#
#
#
#                         980g pigment mtm-charcoal-
#                     </a>
# </p>
# <p class="price">
# <del>82,000원</del>
#                     49,200원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1582356', '1582356', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1582356" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1582356', '1582356', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">49,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">15,703</span>
# </p>
# <p class="txt_cnt_like goods_like_1582356 hide" id="like_1582356">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1582356" onclick="viewOption3(this, '1582356', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1582356" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2149254">
# <p class="n-label label-default txt_num_rank">
#             7위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2149254?loc=goods_rank">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 베이식 긴팔 티셔츠 2팩" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210928/2149254/2149254_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/musinsastandard">무신사 스탠다드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2149254?loc=goods_rank" title="베이식 긴팔 티셔츠 2팩">
#
#
#
#
#                         베이식 긴팔 티셔츠 2팩
#                     </a>
# </p>
# <p class="price">
#
#                     37,800원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-5,670원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2149254', '2149254', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2149254" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2149254', '2149254', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">37,800원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">31,337</span>
# </p>
# <p class="txt_cnt_like goods_like_2149254 hide" id="like_2149254">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2149254" onclick="viewOption3(this, '2149254', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2149254" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1817394">
# <p class="n-label label-default txt_num_rank">
#             8위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1817394?loc=goods_rank">
# <img alt="트래블(TRAVEL) [3-PACK]베이직 트래블러 피그먼트 스웨트셔츠" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210226/1817394/1817394_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/travel">트래블</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1817394?loc=goods_rank" title="[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠">
#
#
#
#
#                         [3-PACK]베이직 트래블러 피그먼트 스웨트셔츠
#                     </a>
# </p>
# <p class="price">
# <del>150,000원</del>
#                     59,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1817394', '1817394', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1817394" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1817394', '1817394', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">59,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 93.0%"></span>
# </span>
# <span class="count">6,872</span>
# </p>
# <p class="txt_cnt_like goods_like_1817394 hide" id="like_1817394">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1817394" onclick="viewOption3(this, '1817394', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1817394" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2194649">
# <p class="n-label label-default txt_num_rank">
#             9위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2194649?loc=goods_rank">
# <img alt="굿라이프웍스(GLW) 카라 케이블 니트 집업 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20211022/2194649/2194649_5_125.png" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/goodlifeworks">굿라이프웍스</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2194649?loc=goods_rank" title="카라 케이블 니트 집업 블랙">
#
#
#
#
#                         카라 케이블 니트 집업 블랙
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     63,000원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-6,300원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2194649', '2194649', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2194649" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2194649', '2194649', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">63,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">4,093</span>
# </p>
# <p class="txt_cnt_like goods_like_2194649 hide" id="like_2194649">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2194649" onclick="viewOption3(this, '2194649', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2194649" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3034895">
# <p class="n-label label-default txt_num_rank">
#             10위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3034895?loc=goods_rank">
# <img alt="스컬프터(SCULPTOR) Velour Soccer Jersey Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230119/3034895/3034895_16752250753178_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/sculptor">스컬프터</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3034895?loc=goods_rank" title="Velour Soccer Jersey Black">
#
#
#
#
#                         Velour Soccer Jersey Black
#                     </a>
# </p>
# <p class="price">
# <del>119,000원</del>
#                     107,100원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3034895', '3034895', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3034895" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3034895', '3034895', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">107,100원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 98.0%"></span>
# </span>
# <span class="count">249</span>
# </p>
# <p class="txt_cnt_like goods_like_3034895 hide" id="like_3034895">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3034895" onclick="viewOption3(this, '3034895', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3034895" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2043036">
# <p class="n-label label-default txt_num_rank">
#             11위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2043036?loc=goods_rank">
# <img alt="코드그라피(CODEGRAPHY) [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트레이닝 셋업_멜란지그레이" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210728/2043036/2043036_16775554791521_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/codegraphy">코드그라피</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2043036?loc=goods_rank" title="[SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트레이닝 셋업_멜란지그레이">
#
#
#
#
#                         [호시 PICK][SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트레이닝 셋업_멜란지그레이
#                     </a>
# </p>
# <p class="price">
# <del>97,900원</del>
#                     72,900원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-7,290원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2043036', '2043036', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2043036" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2043036', '2043036', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">72,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">7,337</span>
# </p>
# <p class="txt_cnt_like goods_like_2043036 hide" id="like_2043036">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2043036" onclick="viewOption3(this, '2043036', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2043036" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1848166">
# <p class="n-label label-default txt_num_rank">
#             12위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1848166?loc=goods_rank">
# <img alt="커버낫(COVERNAT) 에센셜 쿨 코튼 2-PACK 티셔츠 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210316/1848166/1848166_16762625497786_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/covernat">커버낫</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1848166?loc=goods_rank" title="에센셜 쿨 코튼 2-PACK 티셔츠 블랙">
#
#
#
#
#                         에센셜 쿨 코튼 2-PACK 티셔츠 블랙
#                     </a>
# </p>
# <p class="price">
# <del>49,000원</del>
#                     34,300원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1848166', '1848166', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1848166" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1848166', '1848166', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">34,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">40,365</span>
# </p>
# <p class="txt_cnt_like goods_like_1848166 hide" id="like_1848166">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1848166" onclick="viewOption3(this, '1848166', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1848166" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2375962">
# <p class="n-label label-default txt_num_rank">
#             13위
#
#         </p>
# <div class="box-icon-right">
# </div>
# ...
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1742661?loc=goods_rank">
# <img alt="예일(YALE) (23SS) 2 TONE ARCH HOODIE BLACK" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210111/1742661/1742661_5_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/yale">예일</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1742661?loc=goods_rank" title="(23SS) 2 TONE ARCH HOODIE BLACK">
#
#
#
#
#                         (23SS) 2 TONE ARCH HOODIE BLACK
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     55,300원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-5,530원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1742661', '1742661', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1742661" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1742661', '1742661', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">55,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">6,536</span>
# </p>
# <p class="txt_cnt_like goods_like_1742661 hide" id="like_1742661">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1742661" onclick="viewOption3(this, '1742661', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1742661" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3026606">
# <p class="n-label label-default txt_num_rank">
#             86위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3026606?loc=goods_rank">
# <img alt="필루미네이트(FILLUMINATE) 오버핏 그래피티 로고 후디-오트밀" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230116/3026606/3026606_16740279087820_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/filluminate">필루미네이트</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3026606?loc=goods_rank" title="오버핏 그래피티 로고 후디-오트밀">
#
#
#
#
#                         오버핏 그래피티 로고 후디-오트밀
#                     </a>
# </p>
# <p class="price">
# <del>64,000원</del>
#                     44,900원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-4,490원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3026606', '3026606', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3026606" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3026606', '3026606', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">44,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">102</span>
# </p>
# <p class="txt_cnt_like goods_like_3026606 hide" id="like_3026606">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3026606" onclick="viewOption3(this, '3026606', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3026606" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1144989">
# <p class="n-label label-default txt_num_rank">
#             87위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1144989?loc=goods_rank">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 베이식 긴팔 티셔츠 [화이트]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190905/1144989/1144989_3_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/musinsastandard">무신사 스탠다드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1144989?loc=goods_rank" title="베이식 긴팔 티셔츠 [화이트]">
#
#
#
#
#                         베이식 긴팔 티셔츠 [화이트]
#                     </a>
# </p>
# <p class="price">
#
#                     18,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1144989', '1144989', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1144989" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1144989', '1144989', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">18,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">66,714</span>
# </p>
# <p class="txt_cnt_like goods_like_1144989 hide" id="like_1144989">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1144989" onclick="viewOption3(this, '1144989', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1144989" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2722805">
# <p class="n-label label-default txt_num_rank">
#             88위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2722805?loc=goods_rank">
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - BURGUNDY" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220817/2722805/2722805_16764270486280_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/brownbreath">브라운브레스</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2722805?loc=goods_rank" title="TAG HOODIE - BURGUNDY">
#
#
#
#
#                         TAG HOODIE - BURGUNDY
#                     </a>
# </p>
# <p class="price">
#
#                     79,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2722805', '2722805', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2722805" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2722805', '2722805', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">79,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">839</span>
# </p>
# <p class="txt_cnt_like goods_like_2722805 hide" id="like_2722805">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2722805" onclick="viewOption3(this, '2722805', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2722805" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1558847">
# <p class="n-label label-default txt_num_rank">
#             89위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1558847?loc=goods_rank">
# <img alt="수아레(SUARE) [리뉴얼] 하프 터틀넥 니트 세트" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200821/1558847/1558847_13_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/suare">수아레</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1558847?loc=goods_rank" title="[리뉴얼] 하프 터틀넥 니트 세트">
#
#
#
#
#                         [리뉴얼] 하프 터틀넥 니트 세트
#                     </a>
# </p>
# <p class="price">
# <del>66,000원</del>
#                     39,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1558847', '1558847', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1558847" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1558847', '1558847', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">39,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">27,192</span>
# </p>
# <p class="txt_cnt_like goods_like_1558847 hide" id="like_1558847">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1558847" onclick="viewOption3(this, '1558847', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1558847" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2319988">
# <p class="n-label label-default txt_num_rank">
#             90위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2319988?loc=goods_rank">
# <img alt="인템포무드(INTEMPOMOOD) 해비 코튼 썸홀 후디 : 15color" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220121/2319988/2319988_25_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/intempomood">인템포무드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2319988?loc=goods_rank" title="해비 코튼 썸홀 후디 : 15color">
#
#
#
#
#                         해비 코튼 썸홀 후디 : 15color
#                     </a>
# </p>
# <p class="price">
# <del>87,000원</del>
#                     73,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2319988', '2319988', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2319988" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2319988', '2319988', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">73,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">5,285</span>
# </p>
# <p class="txt_cnt_like goods_like_2319988 hide" id="like_2319988">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2319988" onclick="viewOption3(this, '2319988', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2319988" style="display:none;"></div>
# </div>
# </li>
# </ul>
# </div>
# <div class="pagingNumber-box box">
# <span class="pagingNumber">
# <span class="totalPagingNum">100</span>
#         페이지 중
#         <span class="currentPagingNum">1</span>
#         페이지
#
# </span>
# </div>
# <div class="pagination-box box">
# <div class="pagination bottom">
# <div class="wrapper">
# <a class="fa fa-angle-double-left paging-btn btn first" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">첫 페이지</label>
# </a>
# <a class="fa fa-angle-left paging-btn btn prev" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">이전</label>
# </a>
# <a class="paging-btn btn active" href="javascript:mss.ranking.goods.page(1);">1</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(2);">2</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(3);">3</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(4);">4</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(5);">5</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(6);">6</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(7);">7</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(8);">8</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(9);">9</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(10);">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:mss.ranking.goods.page(11);">
# <label style="display:none">다음</label>
# </a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:mss.ranking.goods.page(100);">
# <label style="display:none">마지막 페이지</label>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/contents/goods.js" type="text/javascript"></script>
# <div class="ui-layer-close fixed"></div>
# <meta content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" name="google-site-verification"/>
# <div id="footerCommonPc"></div>
# <div class="ui-layer-close fixed"></div>
# </div>
# </div>
# </body>
# <script>
#         $(function() {
#             removeGfParameter();
#             $('img.lazyload').lazyload();
#         });
#     </script>
# <script src="//static.msscdn.net/static/search/202302272038/js/ranking/goods_pc.js" type="text/javascript"></script>
# </html>

# %%
brand_html=html.select('#goodsRankList > li > div.li_inner > div.article_info > p.item_title > a')
brand_html[0].string
# Out:
# '수아레'

# %%
brand_list=[]
for i in brand_html:
    brand_list.append(i.string)
brand_list[0:10]
# Out:
# ['수아레',
#  '무신사 스탠다드',
#  '스파오',
#  '예일',
#  '토피',
#  '소버먼트',
#  '무신사 스탠다드',
#  '트래블',
#  '굿라이프웍스',
#  '스컬프터']

# %%
##경로: #goodsRankList > li:nth-child(1) > div.li_inner > div.article_info > p.list_info > a

# %%
html.select('#goodsRankList > li:nth-child(1) > div.li_inner > div.article_info > p.list_info > a')
# Out:
# [<a href="https://www.musinsa.com/app/goods/2396645?loc=goods_rank" title="워셔블 하찌 니트 - 11 COLOR">
#
#
#
#
#                          워셔블 하찌 니트 - 11 COLOR
#                      </a>]

# %%
link_name_html=html.select('#goodsRankList > li > div.li_inner > div.article_info > p.list_info > a')
link_list=[]
name_list=[]
for i in link_name_html:
    link_list.append(i['href'])
    name_list.append(i['title'])
link_list[0:5], name_list[0:5]
# Out:
# (['https://www.musinsa.com/app/goods/2396645?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/2086653?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/2272830?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/2326935?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/2314616?loc=goods_rank'],
#  ['워셔블 하찌 니트 - 11 COLOR',
#   '레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]',
#   '(시티보이) 오버핏 옥스포드 셔츠_SPYWD23C01',
#   '(23SS) 2 TONE ARCH HOODIE GRAY',
#   '에센셜 후드 스웻 셔츠 (MELANGE GREY)'])

# %%
rank_html=html.select('#goodsRankList > li > p')
rank_no_list=[]
for i in rank_html:
    rank_no_list.append(i.string.strip())
rank_no_list[0:5]
# Out:
# ['1위', '2위', '3위', '4위', '5위']

# %%
#상세 정보에 대한 페이지 접근 시 403 오류가 뜨는 것을 확인 가능
a=requests.get(link_list[0])
a.status_code
# Out:
# 403

# %%
#headers을 설정해주어야 했고, header에 대한 값을 추가
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36'}
response_1=requests.get(link_list[32],headers=headers)
response_1.status_code
# Out:
# 200

# %%
html_1=bs(response_1.text, 'lxml')
html_1
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- Google Tag Manager -->
# <script>
# var selfCertEnabled = "" || "Y";
# var THIS_PAGE_GF = 'A'; // 전역필터 상태값 caching page reload 필요 체크용
# var dataLayer = window.dataLayer || [];
# window.addEventListener("DOMContentLoaded", function() {
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');
# }, false);
# </script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico?20200213" rel="shortcut icon" type="image/x-icon"/>
# <meta content="제품분류 : 상의 &gt; 후드 티셔츠 브랜드 : 브라운브레스(BROWNBREATH) 제품번호 : BHWMHDB10AS 제품 : TAG HOODIE - ASH - 79,000 원산지 : 대한민국 " name="description"/>
# <!-- 페이스북 오픈 그래프 메타태그  -->
# <meta content="648837775133366" id="fbAddId" property="fb:app_id"/>
# <meta content="website" id="fbOgType" property="og:type"/>
# <meta content="브라운브레스(BROWNBREATH) TAG HOODIE - ASH - 79,000 | 무신사 스토어" id="fbOgTitle" property="og:title"/>
# <meta content="https://image.msscdn.net/images/goods_img/20200901/1574201/1574201_16735742721712_500.jpg" id="fbOgImage" property="og:image"/>
# <meta content="제품분류 : 상의 &gt; 후드 티셔츠 브랜드 : 브라운브레스(BROWNBREATH) 제품번호 : BHWMHDB10AS 제품 : TAG HOODIE - ASH - 79,000 원산지 : 대한민국 " id="fbOgDescription" property="og:description"/>
# <meta content="https://www.musinsa.com/app/goods/1574201?loc=goods_rank&amp;_gf=A" id="fbOgUrl" property="og:url"/>
# <!--// 페이스북 오픈 그래프 메타태그 -->
# <title>브라운브레스(BROWNBREATH) TAG HOODIE - ASH - 79,000 | 무신사 스토어</title>
# <link href="//static.msscdn.net/static/common/1.2.0/pc.css" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/ui/build/pc/css/common.css?202109290900" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202202150915" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/store_common.css?202112011113" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202201131000" rel="stylesheet" type="text/css"/>
# <link href="//image.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202101051200" rel="stylesheet"/>
# <link href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202302131400" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/style.min.css?202302131400" rel="stylesheet" type="text/css"/> <link href="//static.msscdn.net/skin/musinsa/css/sub.css?202302131400" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/media_query.css?202010301640" rel="stylesheet" type="text/css"/>
# <!--<link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/font.css?20170221" />-->
# <link href="//static.msscdn.net/skin/musinsa/css/new.css?202112010912" rel="stylesheet" type="text/css"/>
# <!-- Swiper -->
# <link href="//static.msscdn.net/swiper/swiper.min.css" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/swiper/swiper.min.js?20200316"></script>
# <!-- Polyfill -->
# <script>
#     if (/MSIE \d|Trident.*rv:/.test(navigator.userAgent)) {
#         (function (w, d, s) {
#             var f = d.getElementsByTagName(s)[0];
#             var j = d.createElement(s);
#             j.async=true;
#             j.src= '//static.msscdn.net/skin/musinsa/js/polyfill.min.js?features=Array.from,Promise,fetch&flags=always';
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script');
#     }
# </script>
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?20160201" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/base.js?20160201" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/common.js?202105041500" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?20160201" type="text/javascript"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/skin/musinsa/js/mini_cart.js?202303081910" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/common.js?202303060850" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?20160202" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?20160202" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jslib.js?20200601" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?20180503" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?20170406" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/ui.js?202203221100" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/common/1.2.0/chunk-vendors.js"></script>
# <script src="//static.msscdn.net/skin/js/app/app.js?af644e13817771c6c6cf"></script>
# <!--jqModal-->
# <link href="//static.msscdn.net/skin/musinsa/css/jqModal.css?20160119" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?20160511" type="text/javascript"></script>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/skin/musinsa/css/image_search.css?202201051301" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/static/search/js/common/pc/search/image_search.js?20220127" type="text/javascript"></script>
# <script type="text/javascript">
#     var search_front_url = "https://search.musinsa.com";
#
#     $(document).ready(function(){
#         if (window.image_search) {
#             window.image_search.setUrl(search_front_url);
#         }
#     });
#
# </script>
# <!-- //유사 이미지 상품 검색 -->
# <link href="https://www.musinsa.com/app/goods/1574201" rel="canonical"/>
# <link href="//static.msscdn.net/ui/build/pc/css/goods.css" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/product.min.css?202301111800" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?20160119"></script>
# <script>
#     var dataLayer = window.dataLayer || [],
#         stateAll = {"isDebug":false,"isGoodsViewExcludingService":false,"isGoodsReviewExcludingService":false,"params":{"goodsNo":"1574201","goodsSub":0,"sort":"new","selectSimilarNo":"","isSecret":"0","isCache":"Y","sex":0,"wh":"","loc":"goods_rank","pGoodsNo":"","cacheFlush":"","rcdr":""},"IS_LOGIN":"N","app_yn":"N","goods_no":"1574201","goods_sub":0,"productInfo":{"goods_nm":"TAG HOODIE - ASH","goods_nm_eng":"TAG HOODIE - ASH","sale_stat_cl":"40","sex":"6","acc_buy_yn":"Y","category":"Clothing > \ud2f0\uc154\uce20 > \ud6c4\ub4dc \ud2f0\uc154\uce20","baseCategoryName":"\ud6c4\ub4dc \ud2f0\uc154\uce20","season_type_nm":"S\/S","similar_no":"2722789","normal_price":"79000","price":"79000","reg_dm":"20200901","brand":"brownbreath","opt_kind_cd":"CLOTHES","brand_nm":"\ube0c\ub77c\uc6b4\ube0c\ub808\uc2a4","brand_nm_eng":"BROWNBREATH","size_opt_kind":"2909173","size_opt_kind_nm":"S","offline_com_id":"S","ori_avg_est_value":"4.8683","season":"2023","goods_type":"P","sale_rate":0,"estimate_cnt":15144,"com_id":"brownbreath_1","img":"\/images\/goods_img\/20200901\/1574201\/1574201_16735742721712_500.jpg","goods_no":"1574201","goods_sub":0,"restock_yn":"N","sales_graph_data":"{}","orders_graph_yn":"Y","es_pageview_yn":"Y","img_prd_list":[{"type":"7","kind":"L","big_img":"\/images\/goods_img\/20200901\/1574201\/1574201_16735742721712_big.jpg","img":"\/images\/goods_img\/20200901\/1574201\/1574201_16735742721712_500.jpg","thumb_img":"\/images\/goods_img\/20200901\/1574201\/1574201_16735742721712_60.jpg","img_ext":"jpg","width":null,"height":null,"seq":"2","rep_yn":"Y","big_yn":"Y"},{"type":"26","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742782069_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742782069_500.jpg","thumb_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742782069_60.jpg","img_ext":"jpg","width":"1500","height":"1800","seq":"1","rep_yn":"Y","big_yn":"Y"},{"type":"27","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742792412_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742792412_500.jpg","thumb_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742792412_60.jpg","img_ext":"jpg","width":"1500","height":"1800","seq":"2","rep_yn":"N","big_yn":"Y"},{"type":"28","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742803119_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742803119_500.jpg","thumb_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742803119_60.jpg","img_ext":"jpg","width":"1500","height":"1800","seq":"3","rep_yn":"N","big_yn":"Y"},{"type":"29","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742814139_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742814139_500.jpg","thumb_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735742814139_60.jpg","img_ext":"jpg","width":"1500","height":"1800","seq":"4","rep_yn":"N","big_yn":"Y"},{"type":"30","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735743754247_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735743754247_500.jpg","thumb_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735743754247_60.jpg","img_ext":"jpg","width":"1500","height":"1800","seq":"5","rep_yn":"N","big_yn":"Y"},{"type":"31","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735743968105_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735743968105_500.jpg","thumb_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735743968105_60.jpg","img_ext":"jpg","width":"1500","height":"1800","seq":"6","rep_yn":"N","big_yn":"Y"},{"type":"32","kind":"D","big_img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735744012695_big.jpg","img":"\/images\/prd_img\/20200901\/1574201\/detail_1574201_16735744012695_50 ...
#     ;
#     stateAll.header_sex = '';
#     var goods_type = 'P';
#         var restock_yn = stateAll.productInfo.restock_yn,
#         offline_com_id = stateAll.productInfo.offline_com_id,
#         used_yn = stateAll.productInfo.used_yn,
#         goods_no = stateAll.productInfo.goods_no,
#         item_cat_nm2 = stateAll.productInfo.baseCategoryName,
#         similar_goods_update_yn = stateAll.similarGoodsSearch.update_yn
#     ;
#
#
#     try {
#         dataLayer.push({
#             'dimension12' : stateAll.productInfo.brand,
#             'productInfo' : {
#                 "email": stateAll.userInfo.email,
#                 "header_sex": stateAll.header_sex,
#                 "goods_no": stateAll.productInfo.goods_no,
#                 "goods_sub": stateAll.productInfo.goods_sub,
#                 "goods_nm": stateAll.productInfo.goods_nm,
#                 "category": stateAll.productInfo.item_cat_cds.nm1 + '>' + stateAll.productInfo.item_cat_cds.nm2,
#                 "category_ga": stateAll.productInfo.category,
#                 "brand": stateAll.productInfo.brand,
#                 "season": stateAll.productInfo.season + ' ' + stateAll.productInfo.season_type_nm,
#                 "sex": stateAll.productInfo.sex,
#                 "goods_type": getGoodsTypeValue(),
#                 "price": stateAll.productInfo.price,
#                 "specialty_code": stateAll.productInfo.specialty_codes,
#                 "currency": "KRW"
#             }
#         });
#     }catch(e){
#         alert('죄송합니다. 내부 서버 문제로 페이지를 불러올 수 없습니다.');
#         location.href = '/';
#     }
#
#     function getGoodsTypeValue() {
#         if (!!stateAll.blackFridayEventGoodsFlag) {
#             return stateAll.productInfo.goods_type+"B";
#         } else {
#             return stateAll.productInfo.goods_type;
#         }
#     }
#
# </script>
# </head><body>
# <!-- 팝업 공지사항 -->
# <!-- 상단 콘텐츠 영역 -->
# <script>
# 	var mss = {
# 		ui: {
# 			loggedIn: false,
# 			top: {
# 				extendBannerList: { // 상단 배너 리스트
# 					code: '16MAIN_UP_1_4',
# 					type: 'H',
# 					subject: '16MAIN_UP_1_4_메인 외_0228_봄 아우터 캠페인',
# 					contents: '<a href="/app/banner/check/16MAIN_UP_1_4/1"><span style="display:block;overflow:hidden; height:70px;background-color:#37535A" href="https://www.musinsa.com/app/campaign/index/springouter2023"><img src="//image.musinsa.com/images/banner/2023022810170300000029568.jpg" alt="봄 아우터 캠페인"></span></a>',
# 					extendContents: '',
# 					extendUrl: ''
# 				},
# 				campaignList: [ // 캠페인 리스트
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: 'https://www.musinsa.com/app/campaign/index/springouter2023',
# 									style: 'color: #00D47B',
# 									text: '봄 아우터'
# 								}
# 							},
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: 'https://www.musinsa.com/app/campaign/index/springtrend2023',
# 									style: 'color: #ED0060',
# 									text: '봄 트렌드'
# 								}
# 							},
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: 'https://www.musinsa.com/app/campaign/index/sweatcollection_23ss',
# 									style: 'color: #5800FF',
# 									text: '스웨트'
# 								}
# 							},
#
#
# 				],
# 			},
# 			left: {
# 				category: {
# 					dCatCd: '', // 선택된 카테고리 코드
# 				},
# 			},
# 		}
# 	};
# </script>
# <div class="top-column column top-musinsa" style="display:none">
# <div class="header header-small store_header clearfix" id="short_top_special">
# <div class="main-wrapper wrapper">
# <h1 class="title"><a href="javascript:void(0)" onclick="showShortTopSpecial(); return false;">MUSINSA STORE 메뉴 열기</a></h1>
# </div>
# </div>
# </div>
# <div id="default_top">
# <div id="topCommonPc"></div>
# </div>
# <script src="//static.msscdn.net/static/common/1.2.0/pc.js"></script><!--// 상단 콘텐츠 영역 -->
# <!-- wrap -->
# <div class="wrap" id="page_product_detail">
# <!-- 왼쪽 메뉴 영역 -->
# <div id="leftCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/lnb.js"></script> <!--// 왼쪽 메뉴 영역 -->
# <!-- 오른쪽 콘텐츠 영역 -->
# <div class="right_area page_detail_product">
# <!-- 상단 로케이션 -->
# <div class="pagenation pagenation_dropdown">
# <div class="nav_sub">
# <a href="/">무신사 스토어</a>
# <span class="icon_entity">&gt;</span>
# <a href="/app/contents/brandshop">브랜드숍</a>
# <span class="icon_entity">&gt;</span>
# <a href="https://www.musinsa.com/brands/brownbreath"><span>BROWNBREATH</span> (브라운브레스)</a>
# </div>
# <span class="txt_selected_division">
# </span>
# <div class="nav_sub_dropdown" style="display:none">
# <ul>
# <li><a href="javascript:void(0)">심플/베이직</a></li>
# <li><a href="javascript:void(0)">트레디셔널</a></li>
# <li><a href="javascript:void(0)">컨템포러리</a></li>
# <li><a href="javascript:void(0)">트렌디/어번</a></li>
# <li><a href="javascript:void(0)">뉴 웨이브</a></li>
# <li><a href="javascript:void(0)">댄디/포멀</a></li>
# <li><a href="javascript:void(0)">팝/유니크</a></li>
# <li><a href="javascript:void(0)">심볼/팬시</a></li>
# <li><a href="javascript:void(0)">하이 엔드</a></li>
# <li><a href="javascript:void(0)">스트릿/힙합</a></li>
# <li><a href="javascript:void(0)">마니아/컬처</a></li>
# <li><a href="javascript:void(0)">밀리터리/텍티컬...</a></li>
# <li><a href="javascript:void(0)">스포츠/아웃도어...</a></li>
# <li><a href="javascript:void(0)">엑스게임/액션스포츠...</a></li>
# <li><a href="javascript:void(0)">가방</a></li>
# <li><a href="javascript:void(0)">시계</a></li>
# <li><a href="javascript:void(0)">슈즈</a></li>
# <li><a href="javascript:void(0)">액세서리</a></li>
# <li><a href="javascript:void(0)">헤드웨어</a></li>
# <li><a href="javascript:void(0)">아이웨어</a></li>
# <li><a href="javascript:void(0)">일상용품</a></li>
# <li><a href="javascript:void(0)">코스메틱</a></li>
# </ul>
# </div>
# </div>
# <!-- //상단 로케이션 -->
# <!--brandshop banner-->
# <div class="detail_brand_banner">
# <a href="https://www.musinsa.com/brands/brownbreath"><p class="brandBanner" style="BACKGROUND: url(//image.msscdn.net/images/brand/2018121016375500000061145.png) repeat-x 0px 0px"><img alt="브라운브레스 로고" src="//image.msscdn.net/images/brand/2018121016375500000065593.png"/></p>
# </a>
# </div>
# <!--//brandshop banner-->
# <div class="right_contents section_product_summary">
# <div class="product_info">
# <p class="item_categories">
# <a href="https://www.musinsa.com/categories/item/001">상의</a> &gt; <a href="https://www.musinsa.com/categories/item/001004">후드 티셔츠</a>
# <a href="https://www.musinsa.com/brands/brownbreath?category1DepthCode=001&amp;category2DepthCodes=001004&amp;category3DepthCodes=">
#             (브라운브레스)        </a>
# </p>
# </div>
# <p class="box_state box-state-multi product_label">
# <span class="n-label label-limit">한정 판매</span>
# <!--[D]래플 뱃지 추가-->
# <!--//[D]래플 뱃지 추가-->
# </p>
# <span class="product_title">
# <em>TAG HOODIE - ASH</em>
# </span>
# <div class="share-block">
# <!-- 페북공유 -->
# <a class="share-button" href="javascript:void(0)" onclick="snsWin('f','%EB%B8%8C%EB%9D%BC%EC%9A%B4%EB%B8%8C%EB%A0%88%EC%8A%A4%28BROWNBREATH%29+TAG+HOODIE+-+ASH+-+79%2C000+%7C+%EB%AC%B4%EC%8B%A0%EC%82%AC+%EC%8A%A4%ED%86%A0%EC%96%B4','https://www.musinsa.com/app/goods/1574201/0');dataLayer.push({'layerCategory': '상품상세','layerAction':'공유하기','layerLabel': 'facebook','event' : 'ga_event','nonInteraction' : false});">
# <span class="blind">페이스북으로 공유하기</span>
# <svg height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <circle cx="15" cy="15" id="5y82mredia" r="15"></circle>
# </defs>
# <g fill="none" fill-rule="evenodd">
# <g>
# <g>
# <g transform="translate(-1430 -373) translate(270 250) translate(1160 123)">
# <mask fill="#fff" id="g0ln4yhm7b">
# <use xlink:href="#5y82mredia"></use>
# </mask>
# <use fill="#3767B8" fill-rule="nonzero" xlink:href="#5y82mredia"></use>
# <path d="M15.832 22.5v-6.842h2.212l.33-2.667h-2.542v-1.702c0-.772.207-1.299 1.273-1.299h1.36V7.605c-.236-.032-1.043-.105-1.982-.105-1.96 0-3.302 1.242-3.302 3.525v1.966h-2.217v2.667h2.217V22.5h2.651z" fill="#FFF" mask="url(#g0ln4yhm7b)"></path>
# </g>
# </g>
# </g>
# </g>
# </svg> </a>
# <!-- 트위터공유 -->
# <a class="share-button" href="javascript:void(0)" onclick="snsWin('t','%EB%B8%8C%EB%9D%BC%EC%9A%B4%EB%B8%8C%EB%A0%88%EC%8A%A4%28BROWNBREATH%29+TAG+HOODIE+-+ASH+-+79%2C000+%7C+%EB%AC%B4%EC%8B%A0%EC%82%AC+%EC%8A%A4%ED%86%A0%EC%96%B4','https://www.musinsa.com/app/goods/1574201/0');dataLayer.push({'layerCategory': '상품상세','layerAction':'공유하기','layerLabel': 'twitter','event' : 'ga_event','nonInteraction' : false});">
# <span class="blind">트위터로 공유하기</span>
# <svg height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <circle cx="15" cy="15" id="impez0i0da" r="15"></circle>
# </defs>
# <g fill="none" fill-rule="evenodd">
# <g>
# <g>
# <g>
# <g transform="translate(-1470 -373) translate(270 250) translate(1160 123) translate(40)">
# <mask fill="#fff" id="ln3z52jwmb">
# <use xlink:href="#impez0i0da"></use>
# </mask>
# <use fill="#1EA1F1" fill-rule="nonzero" xlink:href="#impez0i0da"></use>
# <path d="M23 10.92c-.558.242-1.152.401-1.772.478.638-.374 1.124-.963 1.353-1.673-.594.35-1.25.595-1.95.733-.564-.592-1.369-.958-2.246-.958-1.703 0-3.074 1.36-3.074 3.028 0 .24.021.472.072.69-2.557-.122-4.82-1.328-6.34-3.166-.264.453-.42.972-.42 1.53 0 1.049.549 1.979 1.367 2.517-.495-.01-.98-.15-1.39-.373v.033c0 1.471 1.066 2.694 2.464 2.975-.25.067-.523.1-.806.1-.198 0-.396-.011-.583-.052.399 1.199 1.529 2.08 2.874 2.11-1.046.805-2.375 1.29-3.813 1.29-.253 0-.494-.01-.736-.041 1.362.865 2.977 1.359 4.717 1.359 5.66 0 8.753-4.616 8.753-8.616 0-.134-.005-.263-.011-.391.61-.427 1.123-.96 1.541-1.573" fill="#FFF" mask="url(#ln3z52jwmb)"></path>
# </g>
# </g>
# </g>
# </g>
# </g>
# </svg> </a>
# <!-- url 복사 -->
# <a class="share-button" href="javascript:void(0)" id="url_copy_detail" onclick="dataLayer.push({'layerCategory': '상품상세','layerAction':'URL복사','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
# <span class="blind">URL 복사하기</span>
# <svg height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <circle cx="15" cy="15" id="gg5hbjhooa" r="15"></circle>
# </defs>
# <g fill="none" fill-rule="evenodd">
# <g>
# <g>
# <g>
# <g transform="translate(-1510 -373) translate(270 250) translate(1160 123) translate(80)">
# <mask fill="#fff" id="eb8wgkfp9b">
# <use xlink:href="#gg5hbjhooa"></use>
# </mask>
# <use fill="#B2B2B2" xlink:href="#gg5hbjhooa"></use>
# <path d="M9.597 18.632c1.581 0 2.632-1.09 2.632-2.931v-3.915h-.974v3.924c0 1.225-.636 1.977-1.658 1.977-1.022 0-1.659-.752-1.659-1.977v-3.924h-.974V15.7c0 1.841 1.051 2.931 2.633 2.931zm5.436-.096v-2.72l2.17 2.72h1.215l-2.218-2.72c.579-.048 1.012-.26 1.33-.578.377-.376.58-.868.58-1.437 0-.579-.213-1.08-.58-1.437-.356-.366-.867-.578-1.542-.578h-1.929v6.75h.974zm.868-3.626h-.868v-2.199h.868c.415 0 .694.107.887.3.183.192.3.472.3.8 0 .318-.107.598-.3.79-.193.184-.463.309-.887.309zm7.683 3.626v-.926h-2.748v-5.824h-.974v6.75h3.722z" fill="#FFF" fill-rule="nonzero" mask="url(#eb8wgkfp9b)"></path>
# </g>
# </g>
# </g>
# </g>
# </g>
# </svg> <input name="copyUrl_detail" type="hidden" value="http://mss.kr/1574201"/>
# </a>
# </div>
# <div class="wrap_product">
# <div class="product_left">
# <!--상품 줌이미지-->
# <div class="product_zoom spotlightActive" id="big_box" style="display:none">
# <div class="product_img_zoom minus_cursor spotlight" id="big_img_area">
# <img alt="" id="big_img" onclick="image_zoom.hideLayer('big_box');" src="" style="position: relative; width: 1500px;"/>
# <span class="product_arrow_prev"><a href="javascript:void(0)" onclick="image_zoom.rollImage('detail_thumb', 'big_img', 'prev'); return false;"><i class="ic-22-line-arrow-left ic-white">이전상품사진</i></a></span>
# <span class="product_arrow_next"><a href="javascript:void(0)" onclick="image_zoom.rollImage('detail_thumb', 'big_img', 'next'); return false;"><i class="ic-22-line-arrow-right ic-white">다음상품사진</i></a></span>
# </div>
# <span class="btn_close_pop" onclick="image_zoom.hideLayer('big_box');">close</span>
# </div>
# <!--//상품 줌이미지-->
# <script type="text/javascript">
#         $(document).ready(function() {
#             // 비디오
#             $('.video_thumb').click( function() {
#                 $('.product_video_frame').toggle('slow', function() {
#                     if($(this).css("display") == 'none') {
#                         // 비디오 레이어 닫힐때 pause
#                         toggleVideo("hide");
#                     } else {
#                         // iframe src 값을 누를 경우에만 호출
#                         var iframe_obj = $("#video_div iframe")
#                         var iframe_src = iframe_obj.attr("src");
#
#                         if(iframe_src == "" || iframe_src == "about:blank") {
#                             iframe_obj.attr("src", iframe_obj.attr("data"));
#                         }
#                     }
#                 });
#             });
#             $('.product_video_frame .video_frame_close' ).click(function() {
#                 $('.product_video_frame').toggle('slow', function() {
#                     // 닫기 버튼 클릭 시 pause
#                     toggleVideo("hide");
#                 });
#             });
#         });
#     </script>
# <!--상품 비디오-->
# <div class="product_video_frame" id="video_div" style="display:none">
# <iframe allowfullscreen="" data="https://www.youtube.com/embed/CpPg9_2vur4?enablejsapi=1" frameborder="0" height="534" src="about:blank" width="100%"></iframe>
# <span class="video_frame_close">close</span>
# </div>
# <!--//상품 비디오-->
# <div class="product_img_basic" id="detail_bigimg">
# <span class="product_arrow_prev">
# <a href="javascript:;" onclick="rollImage('0','8', 'bigimg');">
# <i class="ic-30-stencil-arrow-left ic-white">이전상품사진</i>
# </a>
# </span>
# <div class="product-img">
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" class="plus_cursor" id="bigimg" onclick="image_zoom.showLayer('big_box', 'big_img', 'detail_thumb', currentImageIdx);" src="//image.msscdn.net/images/goods_img/20200901/1574201/1574201_16735742721712_500.jpg" title="" width="500"/><span class="vertical_standard"></span>
# </div>
# <span class="product_arrow_next">
# <a href="javascript:;" onclick="rollImage('1','8', 'bigimg');">
# <i class="ic-30-stencil-arrow-right ic-white">다음상품사진</i>
# </a>
# </span>
# <div class="btn-imagesearch">
# <a class="btn-smartsearch" href="javascript:void(0);" onclick="ga('send', 'event', 'SMARTSEARCH', 'click', 'PC');dataLayer.push({'layerCategory': '상품상세','layerAction':'이미지서치','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
#                 비슷한 스타일 <i class="ic-14-line-arrow-right ic-white"></i>
# </a>
# </div>
# </div>
# <!--상품 썸네일-->
# <div id="detail_thumb">
# <ul class="product_thumb">
# <li class="selected" onmouseenter="changeImg('thum_0', 'bigimg', '0', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_0" src="//image.msscdn.net/images/goods_img/20200901/1574201/1574201_16735742721712_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_1', 'bigimg', '1', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_1" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735742782069_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_2', 'bigimg', '2', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_2" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735742792412_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_3', 'bigimg', '3', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_3" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735742803119_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_4', 'bigimg', '4', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_4" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735742814139_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_5', 'bigimg', '5', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_5" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735743754247_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_6', 'bigimg', '6', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_6" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735743968105_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li onmouseenter="changeImg('thum_7', 'bigimg', '7', 'Y');" style="cursor: pointer;"><!-- class="selected" -->
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" big_yn="Y" id="thum_7" src="//image.msscdn.net/images/prd_img/20200901/1574201/detail_1574201_16735744012695_60.jpg" style="display: inline-block; vertical-align: middle" width="60"/><span class="vertical_standard"></span>
# </li>
# <li class="video_thumb"><img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH 비디오" src="//image.msscdn.net/skin/musinsa/images/thumb-video.gif?20150918"/></li>
# </ul>
# <!--//상품 썸네일-->
# </div>
# <div class="box_material">
# <!--사이즈정보-->
# <h4 class="title-box font-mss">Size Info<span class="korSub">사이즈정보</span></h4>
# <div class="box_size improve">
# <a href="javascript:void(0)" onclick="write_size(21, '029001006'); return false;"><strong>구매내역 실측 선택</strong></a>
# <a href="javascript:void(0)" onclick="goMySize('21'); return false;"><strong>실측 직접 입력</strong></a>
# <a href="javascript:void(0)" onclick="window.open('/app/product/real_size#21','realsize', 'width=360, height=845, scrollbars=yes, resizalbe=no, left=400, top=100'); return false;"><strong>측정법</strong></a>
# </div>
# <!--//사이즈추천 개선 - 버튼-->
# <!--사이즈추천 개선-->
# <table class="table_th_grey" id="size_table">
# <thead>
# <tr>
# <th>cm</th>
# <th class="item_val">
# <input name="diff_range_0" type="hidden" value="5"/>
#                                 총장
#                             </th>
# <th class="item_val">
# <input name="diff_range_1" type="hidden" value="5"/>
#                                 어깨너비
#                             </th>
# <th class="item_val">
# <input name="diff_range_2" type="hidden" value="5"/>
#                                 가슴단면
#                             </th>
# <th class="item_val">
# <input name="diff_range_3" type="hidden" value="5"/>
#                                 소매길이
#                             </th>
# </tr>
# </thead>
# <tbody>
# <tr id="mysize">
# <th>MY</th>
# <td colspan="5">가지고 계신 제품의 실측을 입력해 보세요~!</td>
# </tr>
# <tr class="order_size_save" id="save_mysize" style="display:none">
# <td colspan="6">
# <a href="javascript:void(0)" onclick="save_size('21'); return false;">위 구매 내역의 사이즈를 저장하시겠습니까?</a>
# <input name="size_info" type="hidden" value=""/>
# </td>
# </tr>
# <tr>
# <th>S(쭈리/ blue)</th>
# <td class="goods_size_val">67</td>
# <td class="goods_size_val">54</td>
# <td class="goods_size_val">58.5</td>
# <td class="goods_size_val">58</td>
# </tr>
# <tr>
# <th>M(쭈리/ blue)</th>
# <td class="goods_size_val">69</td>
# <td class="goods_size_val">56</td>
# <td class="goods_size_val">61</td>
# <td class="goods_size_val">59</td>
# </tr>
# <tr>
# <th>L(쭈리/ blue)</th>
# <td class="goods_size_val">71</td>
# <td class="goods_size_val">58</td>
# <td class="goods_size_val">63.5</td>
# <td class="goods_size_val">60</td>
# </tr>
# <tr>
# <th>XL(쭈리/ blue)</th>
# <td class="goods_size_val">73</td>
# <td class="goods_size_val">60</td>
# <td class="goods_size_val">66</td>
# <td class="goods_size_val">61</td>
# </tr>
# <tr>
# <th>S(기모 / green)</th>
# <td class="goods_size_val">67</td>
# <td class="goods_size_val">54</td>
# <td class="goods_size_val">58.5</td>
# <td class="goods_size_val">58</td>
# </tr>
# <tr>
# <th>M(기모 / green)</th>
# <td class="goods_size_val">69</td>
# <td class="goods_size_val">56</td>
# <td class="goods_size_val">61</td>
# <td class="goods_size_val">59</td>
# </tr>
# <tr>
# <th>L(기모 / green)</th>
# <td class="goods_size_val">71</td>
# <td class="goods_size_val">58</td>
# <td class="goods_size_val">63.5</td>
# <td class="goods_size_val">60</td>
# </tr>
# <tr>
# <th>XL(기모 / green)</th>
# <td class="goods_size_val">73</td>
# <td class="goods_size_val">60</td>
# <td class="goods_size_val">66</td>
# <td class="goods_size_val">61</td>
# </tr>
# </tbody>
# </table>
# <ul class="n-info-txt">
# <li>위 사이즈 표는 무신사스토어 측정방식을 기준으로 작성되었습니다.</li>
# <li>보유하신 옷의 실측값을 입력하시면 정확한 비교가 가능합니다.</li>
# <li>상품 상세 정보의 사이즈 표는 업체 기준 측정입니다.</li>
# </ul>
# <div class="product-note-box">
# <i class="ic-30-stencil-exclamation"></i>
# <ul class="n-info-txt">
# <li>상품 이미지는 모니터 해상도, 색상 설정에 따라 이미지가 왜곡되거나 실제 색상과 차이가 있을 수 있습니다.</li>
# <li>사이즈 실측은 상품의 특성 및 측정방식에 따라 오차가 발생할 수 있습니다.</li>
# </ul>
# </div>
# <!--//사이즈정보-->
# </div>
# <!--사이즈 소재 정보-->
# <div class="box_material">
# <h4 class="title-box font-mss">Guide<span class="korSub">가이드</span></h4>
# <table class="table-simple">
# <tbody>
# <tr>
# <th>핏</th>
# <td>스키니</td>
# <td>슬림</td>
# <td>레귤러</td>
# <td>루즈</td>
# <td class="active">오버 사이즈</td>
# </tr>
# <tr>
# <th>촉감</th>
# <td class="active">부드러움</td>
# <td>약간 부드러움</td>
# <td>보통</td>
# <td>약간 뻣뻣함</td>
# <td>뻣뻣함</td>
# </tr>
# <tr>
# <th>신축성</th>
# <td>없음</td>
# <td>거의 없음</td>
# <td class="active">보통</td>
# <td>약간 있음</td>
# <td>있음</td>
# </tr>
# <tr>
# <th>비침</th>
# <td>있음</td>
# <td>약간 있음</td>
# <td>보통</td>
# <td>거의 없음</td>
# <td class="active">없음</td>
# </tr>
# <tr>
# <th>두께</th>
# <td>얇음</td>
# <td>약간 얇음</td>
# <td>보통</td>
# <td>약간 두꺼움</td>
# <td class="active">두꺼움</td>
# </tr>
# <tr>
# <th>계절</th>
# <td class="active">봄</td>
# <td>여름</td>
# <td class="active">가을</td>
# <td class="active">겨울</td>
# <td> </td>
# </tr>
# </tbody>
# </table>
# </div>
# <!-- //사이즈 소재 정보--> </div>
# <div class="product_right product_order_info" id="product_order_info" style="padding-left:15px">
# <div class="explan_product product_info_section">
# <div class="exclusive_info">
# <b>한정 판매</b>
# <p>무신사 스토어를 포함한 제한된 판매처에서만 구매 가능한 상품입니다.</p>
# </div>
# <h4 class="title-box font-mss">Product Info<span class="korSub">제품정보</span></h4>
# <ul class="product_article">
# <li>
# <p class="product_article_tit">브랜드 <span class="txt_unit2">/</span> 품번 </p>
# <p class="product_article_contents"><strong><a href="https://www.musinsa.com/brands/brownbreath">BROWNBREATH</a> <span class="txt_unit2">/</span> BHWMHDB10AS</strong></p>
# </li>
# <li>
# <p class="product_article_tit">
# <span class="tooltip">
# <a class="ui-toggle-btn">시즌 <i class="ic-22-stencil-question ic-gray6">도움말 보기</i></a>
# <span class="n-tooltip tooltip-musinsa fade-in">이전 시즌과 동일하게 재생산된 제품은, 캐리오버 또는 최종으로 생산된
# 시즌을 기준으로 표시될 수 있습니다.</span>
# </span>
# <span class="txt_unit2">/</span>
#                  성별
#             </p>
# <p class="product_article_contents">
# <strong> 2023                          S/S
#                                             </strong>
# <span class="txt_unit2">/</span>
# <span class="txt_gender">
# <span>남</span>
# <span>여</span>
# </span>
# </p>
# </li>
# <li id="li_pageview_1m" style="display:none;">
# <p class="product_article_tit">조회수(1개월)</p>
# <p class="product_article_contents">
# <strong id="pageview_1m"></strong>
# </p>
# </li>
# <li id="li_sales_1y" style="display:none;">
# <p class="product_article_tit">누적판매(1년)</p>
# <p class="product_article_contents"><strong id="sales_1y_qty"></strong><span class="pageview_number">(결제완료-반품)</span></p>
# </li>
# <!--좋아요-->
# <li class="product_section_like hide" id="product-top-like">
# <p class="product_article_tit">좋아요</p>
# <p class="product_article_contents goods_like_1574201"><img alt="" src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span class="prd_like_cnt">0</span>
# </p>
# </li>
# <!--//좋아요-->
# <li>
# <p class="product_article_tit">
#                     구매 후기
#                                             <span class="tooltip">
# <a class="ui-toggle-btn"><i class="ic-22-stencil-question ic-gray6">도움말 보기</i></a>
# <span class="n-tooltip tooltip-musinsa fade-in">모든 컬러의 상품 후기가 통합 노출됩니다.<br/>하단에서 필터로 컬러별 후기를 조회할 수 있습니다.</span>
# </span>
# </p>
# <p class="product_article_contents">
# <a class="prd-score__link" href="#estimateBox">
# <span class="img-score"><span class="bar" style="width: 98%"></span></span>
# <span class="prd-score__rating">4.9</span>
# <span class="prd-score__bar">/</span>
# <span class="prd-score__review-count">후기 4,483개 보기</span>
# </a>
# </p>
# </li>
# <li class="article-tag-list list">
# <p class="product_article_contents">
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=%EB%A1%9C%EA%B3%A0%ED%8B%B0">#로고티</a>
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=%EC%98%A4%EB%B2%84%ED%95%8F%ED%9B%84%EB%93%9C">#오버핏후드</a>
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=%EA%B8%B0%EB%AA%A8%ED%9B%84%EB%93%9C">#기모후드</a>
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=%EB%A1%9C%EA%B3%A0%ED%9B%84%EB%93%9C">#로고후드</a>
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=%EC%8A%A4%EC%9B%A8%ED%8A%B8%EC%85%94%EC%B8%A0">#스웨트셔츠</a>
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=TAG%EB%A1%9C%EA%B3%A0">#TAG로고</a>
# <a class="listItem" href="https://www.musinsa.com/search/musinsa/integration?q=%EC%8A%A4%EC%9B%A8%ED%8A%B8%ED%8E%98%EC%8A%A4%ED%8B%B0%EB%B2%8C">#스웨트페스티벌</a>
# </p>
# </li>
# </ul>
# </div>
# <!--//제품정보-->
# <a class="explan_product n-stats-summary" href="#" id="graph_summary_area" style="display:none;"></a>
# <div class="explan_product delivery_info_section">
# <h4 class="title-box font-mss">Delivery Info<span class="korSub">배송정보</span></h4>
# <ul class="product_article">
# <!-- 출고정보 -->
# <li>
# <p class="product_article_tit">
# <span class="tooltip">
# <a class="ui-toggle-btn">출고 정보 <i class="ic-22-stencil-question ic-black">도움말 보기</i></a>
# <span class="n-tooltip tooltip-musinsa fade-in">판매자가 설정한 정보로, 업체 및 상품상황에 따라 변경될 수 있습니다. 주말, 공휴일 및 업체 휴무일 제외한 평일(영업일) 기준 일자 입니다.</span>
# </span>
# </p>
# <p class="product_article_contents">
#                                                                             결제 3일 이내 출고
#                                             </p>
# </li>
# <!-- 배송 정보 -->
# <li class="box_info_products">
# <p class="product_article_tit">배송 정보</p>
# <p class="product_article_contents">국내 배송 <span class="txt_unit2">/</span>  입점사 배송 <span class="txt_unit2">/</span> 롯데택배</p>
# </li>
# <li>
# <div class="MArrivalInformation">
# <div class="MArrivalInformation__list MArrivalInformation__list--accordion product_article_tit">
# <div class="CArrivalInformation">
# <div class="CArrivalInformation__text">3/21(화) 도착 예정</div>
# <div class="CArrivalInformation__arrow">
# <svg fill="none" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
# <path d="M3 6.60001L8.99965 12.6L15 6.60001" stroke="black"></path>
# </svg>
# </div>
# </div>
# <ol class="CArrivalInformationProbability">
# <li class="CArrivalInformationProbability__item CArrivalInformationProbability__item--active">
# <span class="CArrivalInformationProbability__text">3/21(화)까지 도착 확률 </span>
# <span class="CArrivalInformationProbability__line"></span>
# <span class="CArrivalInformationProbability__number">97%</span>
# </li>
# <li class="CArrivalInformationProbability__item">
# <span class="CArrivalInformationProbability__text">3/22(수)까지 도착 확률 </span>
# <span class="CArrivalInformationProbability__line"></span>
# <span class="CArrivalInformationProbability__number">99%</span>
# </li>
# </ol>
# </div>
# <p class="CArrivalInformationNotice">최근 1개월의 배송 데이터를 기반으로 예상한 도착일입니다. 도착일은 배송지나 택배사 사정 등으로 변경될 수 있습니다.</p>
# </div>
# </li>
# </ul>
# </div>
# <!--//배송정보-->
# <!-- 가격정보 -->
# <div class="explan_product price_info_section">
# <h4 class="title-box font-mss">Price Info<span class="korSub">가격정보</span></h4>
# <ul class="product_article">
# <li id="normal_price" style="display: none;">79000</li>
# <li class="box_info_products">
# <p class="product_article_tit">무신사 판매가</p>
# <p class="product_article_contents">
# <span class="product_article_price" id="goods_price">
#                                                                                                                                                 79,000원
#                     </span>
# </p>
# </li>
# <!-- 오프라인 상품 여부 -->
# <li class="box_info_products">
# <p class="product_article_tit">무신사 회원가</p>
# <div class="product_article_contents">
# <a class="product_article_price" href="javascript:void(0)" onclick="viewGoodsMemberPrice('sPrice', '1574201', '0'); return false;">
# <span id="list_price"><span class="txt_unit_price">원</span><i class="ic-18-line-arrow-bottom"></i></span>
# </a>
# <div class="member_price" id="sPrice" style="display: none;">
# <p>무신사 회원가<span class="fr"><a href="javascript:void(0)" onclick="viewGoodsMemberPrice('sPrice', '1574201', '0'); return false;">X</a></span></p>
# <!--<p class="member_price_tootip">적립금 선할인이 적용된 회원가입니다</p>-->
# <ul>
# <li class="pertinent"><span class="selected">&gt; </span>비회원<span class="txt_price_member m_list_price">79,000원</span></li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
#                         $(function(){
#                             $.ajax({
#                                 type: "GET",
#                                 url: "/app/svc/member_price_new/" + productInfo.goods_no + "/" + productInfo.goods_sub + "?" + "&type=detail",
#                                 success: function(msg) {
#                                     var first_price = $("#list_price").html(msg).find('.m_list_price').last().text().slice(0,-1);
#                                     var last_price = Comma(stateAll.productInfo.price);
#                                     var cardInfo = stateAll.cardInfo || {max_month:0}
#                                     var listPriceText = first_price + " ~ " + last_price;
#                                     if(first_price === last_price) {
#                                         listPriceText = first_price;
#                                         $("#price_rat, #max_card_price").hide();
#                                     }
#
#                                     $("#list_price").html(listPriceText + "<span class=\"txt_unit_price\">원</span><i class=\"ic-18-line-arrow-bottom\">");
#
#                                     if (Number(stateAll.cardInfo.max_month) > 0 && productInfo.ptn_dc_yn !== 'Y') {
#                                         var min_price = Math.round(unComma(first_price) / cardInfo.max_month);
#                                         $("#min_card_price").html(Comma(min_price));
#                                     }
#
#                                 }
#                             });
#                         });
#                     </script>
# </li>
# <li class="box_info_products">
# <p class="product_article_tit">무신사 적립금</p>
# <p class="product_article_contents"><span class="txt-reserve">최대 3,160원</span>
# </p>
# </li>
# <!--// 오프라인 상품 여부 -->
# </ul>
# <div class="textbox_red">
#         전 상품 무료배송 (가구 등 일부 상품 제외)
#     </div>
# <div class="textbox_black"><a href="/app/content/s/cs/benefit_01">회원 특별 혜택</a></div>
# <div class="access-block">
# </div>
# </div>
# <!--//가격정보-->
# <!-- [D] 테라스 -->
# <!-- //[D] 테라스 -->
# <!--래플-->
# <!--//래플-->
# <!--시뮬레이션-->
# <!--시뮬레이션-->
# <div class="explan_product benefitLayer_section">
# <div class="detail_explan_down">
# <a class="ui-toggle-btn" href="javascript:void(0);" onclick="initializeLowestPriceCalculator(); setDiscountAmt();showHide('benefitLayer');dataLayer.push({'layerCategory': '상품상세','layerAction':'최저가계산기','layerLabel': decodeURIComponent(productInfo.goods_nm),'event' : 'ga_event','nonInteraction' : false});">
# <svg height="18" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <g>
# <g>
# <g>
# <g>
# <path d="M14 0v18H5v-1h8V1H1v16h3v1H0V0h14z" fill="#000" fill-rule="nonzero" transform="translate(-854 -1158) translate(270 250) translate(580 906) translate(4 2)"></path>
# <path d="M3 9H4V10H3zM3 12H4V13H3zM3 15H4V16H3zM6.5 9H7.5V10H6.5zM6.5 12H7.5V13H6.5zM6.5 15H7.5V16H6.5zM10 9H11V10H10zM10 12H11V16H10z" fill="#000" transform="translate(-854 -1158) translate(270 250) translate(580 906) translate(4 2)"></path>
# <path d="M2.5 2.5H11.5V7.5H2.5z" stroke="#000" transform="translate(-854 -1158) translate(270 250) translate(580 906) translate(4 2)"></path>
# </g>
# </g>
# </g>
# </g>
# </g>
# </svg> <strong>최저가 계산기</strong>로 시뮬레이션 해 보실 수 있습니다.
#                 <i class="ic-18-line-arrow-bottom"></i>
# </a>
# </div>
# <div class="box_simulation" id="benefitLayer">
# <ul class="box_simulator">
# <li class="option_box_grey first">
#                         등급 할인 :
#                                                     회원가입 후 혜택을 받으실 수 있습니다.
#                                                 <a href="https://www.musinsa.com/member/benefit" target="_blank"><span class="option_link_right">회원혜택</span></a>
# </li>
# <li class="option_box_grey box_select_check">
#                         적립금 선할인 :
#                                                     <span class="txt_discount" id="prepoint_amt" style="display: none;">0</span>
# <span class="txt_bracket">(적립금 선할인 미적용 상품입니다.)</span>
# <a href="https://www.musinsa.com/member/benefit" target="_blank"><span class="option_link_right">할인제도</span></a>
# </li>
# <li class="option_box_grey">
# <span id="coupon_amt" style="display: none;">0</span>
#                                             쿠폰 할인 : <input disabled="" id="dc_coupon" onclick="popCoupon('1574201', '0');" type="checkbox"/>
# <a href="javascript:void(0)" onclick="alert('로그인 후 사용할 수 있습니다.'); return false;"><span class="option_link_right">쿠폰 내역</span></a>
# </li>
# <li class="option_box_grey">
#                                                     적립금 사용 : <input disabled="" id="dc_point" type="checkbox"/> 사용
#                                                                         </li>
# <li class="option_box_grey displayPlccPlccFirstPay" style="display:none">
# <span id="displayPlccPlccFirstPayText">무신사 현대카드 즉시할인</span>: <input id="ckDcPlccFirstPay" onclick="setDiscountAmt();" type="checkbox"/> 사용 <em id="dcPlccFirstPay">0</em>원
#                         <span id="textFirstPossible" style="display:none;font-size:11px;color:red; display:none"><br/>결제금액 31,000원 이상 사용 가능합니다.</span>
# </li>
# <li class="option_box_grey">
#                         무신사 현대카드 5% 청구할인 : <input id="ckDcPlccBilling" onclick="setDiscountAmt();" type="checkbox"/> 사용 <em id="dcPlccBilling">0</em>원
#                     </li>
# <li class="box_simulator__banner" id="wrapPlccIssuance" style="display:none">
# <a href="/app/campaign/event/musinsa_hyundaicard/129?eventCode=MSS01" title="현대카드 자세히 보기">
# <p class="box_simulator__banner__svg">
# <svg height="14" viewbox="0 0 167 14" width="167" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <g fill="#FFF">
# ...
# <div class="cont-label"><strong>보내실 곳</strong></div>
# <div class="cont-info">
# 	                      12616 경기 여주시 강천면 간매리 320-4 브라운브레스
# 	                      <div class="n-btn-group"><a class="n-btn" href="/app/mypage/order_list_opt">교환 / 환불 접수하기</a></div>
# </div>
# <div class="cont-label">교환/환불 시<br/>주의 사항</div>
# <div class="cont-info">
# <ul class="n-info-txt">
# <li>상품 수령 후 7일 이내 교환/환불을 요청해야 합니다.</li>
# <li>동일 업체일 경우라도 상품별로 반품비용이 상이하게 발생할 수 있습니다.</li>
# <li>교환/환불 시 반품비용은 선결제함으로 동봉하지 마시고, 동봉하여 발송하신 경우 확인 후 반품비 환불 처리됩니다.</li>
# <li>고객님의 사유로 교환 진행 중인 상품이 품절될 경우, 반품비가 발생될 수 있으며 이를 제외한 결제금액이 환불 처리됩니다.</li>
# <li>자동회수 접수 시 영업일 기준 2~3일 내에 택배기사님 연락 후 방문하여 회수 진행됩니다.</li>
# <li>자동회수 미지원 업체 및 직접발송의 경우 수령하신 택배사로 착불(신용)로 반품 접수하여 발송 부탁드리겠습니다.</li>
# <li>수령하신 택배사가 아닌 다른 택배사로 발송하시는 경우(신규 택배 접수 포함) 추가 비용이 발생 할 수 있습니다.</li>
# <li>반품 주소지는 브랜드(업체)마다 다르므로 확인 후 각각 보내셔야 합니다.</li>
# <li>상품의 내용이 표시, 광고 내용과 다르거나 계약 내용이 다를 경우 상품을 공급받은 날부터 3개월 이내, 그 사실을 안 날 또는 알 수 있었던 날부터 30일 내 청약 철회를 할 수 있습니다.</li>
# <li>상품을 반환받은 날로부터 영업일 기준 3일 내 지급받은 대금을 환급합니다.</li>
# <li>미성년자가 체결한 계약은 법정대리인이 동의하지 않는 경우 본인 또는 법정대리인이 취소할 수 있습니다.</li>
# <li>도서산간 지역의 경우 결제하신 기본 교환/환불 배송비 외에 편도 기준 최대 8천원(왕복 기준 최대 16천원)까지 추가 비용이 발생할 수 있습니다. 택배사, 판매업체, 지역별로 도서산간 발생 금액이 상이해 구매 시점에서는 정확한 금액 안내가 어렵습니다.</li>
# </ul>
# </div>
# <div class="cont-label">교환/환불이<br/>불가능한 경우</div>
# <div class="cont-info">
# <ul class="n-info-txt">
# <li>반품 요청 기간(수령 후 7일 이내)이 경과한 경우</li>
# <li>상품을 사용(또는 착용, 착화) 혹은 훼손하여 재판매가 어려울 정도로 상품가치가 현저히 감소한 경우</li>
# <li>상품의 택(Tag) 또는 라벨 제거, 분리, 분실, 훼손하거나<br/>세트 구성품을 누락한 경우</li>
# <li>신발 브랜드 박스를 분실하거나 훼손(오염, 테이핑 등)한 경우<br/>(상품 확인 목적으로 단순 개봉한 경우는 제외)</li>
# <li>상품을 설치/장착하거나 전원을 연결한 경우(테크, 가전 제품 등)</li>
# <li>고객의 주문에 따라 개별적으로 생산된 상품인 경우(맞춤 주문 제작 상품 등)</li>
# </ul>
# <div class="packing-img"></div>
# </div>
# </div>
# </div>
# <div class="cs-info-block">
# <div class="block-tit"><strong>고객센터</strong></div>
# <div class="cs-cont">
# <div class="cont-label font-mss">1544-7199</div>
# <div class="cont-info">
# <div>상품 문의 &gt; 각 상품 Q&amp;A 이용<br/>평일 09:00~18:00 / 토,일,공휴일 휴무</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--//cs안내-->
# <!-- 하단 콘텐츠 영역 -->
# <div id="footerCommonPc"></div>
# <meta content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" name="google-site-verification"/>
# <script async="true" src="//static.msscdn.net/skin/musinsa/js/jquery.url.packed.js" type="text/javascript"></script> <!--// 하단 콘텐츠 영역 -->
# <!--// 오른쪽 콘텐츠 영역 -->
# <div class="ui-layer layer-basic" id="memberCertifyNone">
# <h1 class="layer-tit tit-full">본인인증(미인증) 회원입니다.</h1>
# <div class="layer-cont">지금 인증하고 서비스를 편리하게 이용해보세요.<br/>(나중에 하기 선택 시 인증 없이 주문 가능하며 해당 팝업은 7일간 열리지 않습니다.)</div>
# <div class="btn-set">
# <button class="ui-layer-close n-btn btn-lighter delay-btn" type="button">나중에 하기</button>
# <button class="ui-layer-close n-btn btn-accent check-cert-btn" type="button">본인인증 하기</button>
# </div>
# </div>
# <script type="text/javascript">
#         $(window).on('load', function(){
#             $('.layer-suggest-join').animate({
#                 opacity:1,
#                 right:'64px'
#             },500);
#         });
#
#         function closeEvent(type){
#             if(type == "day"){
#                 setTodayCookie("user_join_event", 1, 1);
#             }
#             $('.layer-suggest-join').remove();
#         }
#
#         function setTodayCookie(key, value, expire){
#             var todayDate = new Date();
#             todayDate = new Date(parseInt(todayDate.getTime() / 86400000) * 86400000 + 54000000);
#             if ( todayDate > new Date() )
#             {
#                 expire = expire - 1;
#             }
#             todayDate.setDate( todayDate.getDate() + expire );
#             document.cookie = key + "=" + escape( value ) + "; path=/; expires=" + todayDate.toGMTString() + "; domain=.musinsa.com"
#         }
#     </script>
# <div class="popup_info layer-suggest-join">
# <div class="wrap-suggest-join">
# <a class="btn-close" href="javascript:void(0);" onclick="closeEvent('day');return false;"><img alt="오늘 하루 열지 않기" src="//image.msscdn.net/skin/musinsa/images/btn_x_23_thin.png"/></a>
# <h4>무신사 회원혜택</h4>
# <p>회원 등급 할인, 적립금, 정기 쿠폰 등<br/>다양한 회원 혜택을 받으세요.</p>
# <p>신규 가입 후 바로 사용 가능한 15% 할인 쿠폰<br/>무신사 스탠다드 990원 구매 기회</p>
# <a class="btn-block-important" href="https://www.musinsa.com/member/join">회원 가입하기</a>
# <a class="btn-block-important join" href="/app/content/s/usr/membership">신규 회원 이벤트</a>
# <div class="link-box">
# <a class="link-login" href="https://www.musinsa.com/auth/login?referer=http%3A%2F%2Fwww.musinsa.com%2Fapp%2Fgoods%2F1574201%3Floc%3Dgoods_rank">로그인 하기</a>
# <a class="day-popup-open" href="javascript:void(0);" onclick="closeEvent('day');return false;">오늘 하루 열지 않기</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--// wrap -->
# <div class="layer_order_size" id="pop_order_size" style="display:none"></div>
# <!--smart search layer-->
# <div class="layer_position wrap-smartsearch-layer" id="wrap-smartsearch-layer" style="display:none">
# <div class="layer-smartsearch">
# <div class="box-left">
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" id="bigimg" src="//image.msscdn.net/images/goods_img/20200901/1574201/1574201_16735742721712_500.jpg" title="" width="500"/><span class="vertical_standard" style="height:600px"></span>
# </div>
# <h4 class="title">비슷한 스타일</h4>
# <a class="btn-close" href="javascript:void(0)"><i class="ic-30-line-close">이미지 서치 팝업 닫기</i></a>
# <div class="wrap-scroll">
# <ul class="list-product" id="image_matching_holder"></ul>
# <img alt="loading" id="smartsearch_loading" src="//image.msscdn.net/skin/musinsa/images/loading2.gif" style="margin:50% 45%"/>
# <input id="search_page" type="hidden" value="1"/>
# <input id="display_cnt" type="hidden" value="12"/>
# </div>
# </div>
# </div>
# <!--무이자 할부 레이어-->
# <div class="wrap-benefit-cart-pop" id="viewCardList" style="display:none">
# <div class="popup_info layer-card-benefit">
# <p class="box_title">
# <span class="title-box"><strong>카드사 할부</strong><span class="korSub">(결제 금액 기준)</span></span>
# <a class="btn_close_pop" href="javascript:void(0)" onclick="viewCardList(); return false;"><img alt="닫기" src="//image.msscdn.net/skin/musinsa/images/btn_close_pop.png"/></a>
# </p>
# <div class="tabBox">
# <ul class="snb snb-2">
# <li class="box-tab-btn tab-btn btn active" data-for="free"><span>무이자 할부</span></li>
# <li class="box-tab-btn tab-btn btn" data-for="part"><span>부분 무이자</span></li>
# </ul>
# <!--무이자 할부-->
# <div class="tab free">
# <ul>
# </ul>
# </div>
# <!--부분 무이자-->
# <div class="tab part">
# <ul>
# <ul class="box-part-benefit">
# </ul>
# </ul></div>
# </div>
# </div>
# </div>
# <!--//무이자 할부 레이어-->
# <!--래플 안내-->
# <div class="layer_cont layer-raffle-info" id="raffle_info" style="display:none; position: fixed; top:215px;">
# <div class="tit">래플</div>
# <div class="info">소비자에게 공정한 기회와 편의를 제공하고자 도입한 온라인 추첨 구입 제도 입니다.<br/>당첨되신 분들께는 무신사스토어를 통해 해당 상품을 구매할 수 있는 기회가 제공됩니다.</div>
# <div class="raffle-route">
# <ul>
# <li class="step-app">
# <i></i>
# <div>
# <span>무신사 앱 접속</span>
#                     앱을 통해서만 응모<br/>가능합니다.
#                 </div>
# </li>
# <li class="step-login">
# <i></i>
# <div>
# <span>무신사 로그인</span>
#                     회원만 1인 1회 응모<br/>가능합니다.
#                 </div>
# </li>
# <li class="step-fill">
# <i></i>
# <div>
# <span>응모 정보 작성</span>
#                     정보가 잘못 입력될 시<br/>응모가 취소될 수 있습니다.
#                 </div>
# </li>
# <li class="step-enter">
# <i></i>
# <div>
# <span>응모하기</span>
#                     응모 후, 완료 팝업을 꼭<br/>확인해 주세요.
#                 </div>
# </li>
# <li class="step-result">
# <i></i>
# <div>
# <span>결과 확인</span>
#                     당첨여부는 SMS<br/>(알림톡)로 안내됩니다.
#                 </div>
# </li>
# <li class="step-buy">
# <i></i>
# <div>
# <span>구매 하기</span>
#                     당첨자에 한하여 발송된<br/>URL에 접속하여 구매하세요.<br/>제한된 시간 내에만 구입이 가능합니다.
#                 </div>
# </li>
# </ul>
# </div>
# <ul class="list-explain">
# <li>상품 별로 응모기간과 발표일, 구매 기간이 다릅니다.</li>
# <li>당첨자는 100% 랜덤 추첨됩니다.</li>
# </ul>
# <a class="btn-close" href="javascript:void(0);"><i class="ico ico-close">레이어 팝업 닫기</i></a>
# </div>
# <!--//래플 안내-->
# <!--래플응모결과 없음-->
# <div class="popup-wrap" id="notexist_popup_wrap" style="width: 100%; height: 100%; position: fixed; display: none; flex-direction: column;  top: 0; z-index: 99999;">
# <div class="layer_cont layer-raffle-none" id="notexist_popup" style="display: none;">
# <a class="btn-close" href="javascript:void(0);" onclick="return false;"><i class="ico ico-close">레이어 팝업 닫기</i></a>
# <div class="tit" id="notexist_title">TAG HOODIE - ASH</div>
# <div class="info">래플에 응모하신 내역이 없습니다.</div>
# </div>
# </div>
# <!--//래플응모결과 없음-->
# <!--래플 당첨결과-->
# <div class="popup-wrap" id="raffle_result_wrap" style="position:absolute;display:none;top:0;z-index:99999;width:100%;min-width:1560px;">
# <div class="layer_cont layer-raffle-result" id="raffle_result" style="display: none;"></div>
# </div>
# <!--//래플 당첨결과-->
# <!--[D]사은품 레이어-->
# <div class="ui-layer layer-basic layer-gift-area" id="getgiftLayer">
# <div class="pop-cont gift-area">
# <p class="txt"><span>0원</span> 이상 구매시 사은품 증정</p>
# <p>특정 상품 추가 구매 시 사은품을 증정합니다.</p>
# <div class="info" data-apply-amt="">
# <div class="img-area"><img alt="" src=""/></div>
# <progress class="progressbar-value" id="progressbar" max="100" value="0"></progress>
# <p class="price"><span></span> / 0원</p>
# </div>
# <a class="pop-btn cart" href="javascript:void(0);" onclick="addCart('1','1574201','0','8', ''); return false;">장바구니 담고 적용상품 보기</a>
# <a class="pop-btn" href="javascript:void(0);" onclick="prepareOrder.directOrder('1','1574201','0'); return false;">바로 구매하기</a>
# </div>
# </div>
# <!--[D]//사은품 레이어-->
# <!-- [D]사은품 적용상품 레이어 -->
# <script type="text/javascript">
#     $(function() {
#         giftLayerHandler.showCartBtn = 1;
#     });
#
#     function addCart(optionCnt, goodsNo, goodsSub, firstOptionCnt, giftNo) {
#         var popAddCart = $(".pop-add-cart");
#         prepareOrder.addCart(optionCnt, goodsNo, goodsSub, function (response, msg, redirectUrl) {
#             if (response === 1) {
#                 msg = '장바구니에 상품 1개가 추가 되었습니다.';
#                 loadCartTotal();
#                 $('#mini_cart > li').remove();
#             }
#             popAddCart.text(msg);
#
#             setTimeout(function(){
#                 $(".pop-add-cart").animate({top:"40px"}, {duration:300, easing:"easeOutCubic"});
#             },500);
#             setTimeout(function(){
#                 $(".pop-add-cart").animate({top:"-48px"}, {duration:300, easing:"easeInCubic"});
#             },3800);
#
#             if (redirectUrl) {
#                 document.location.href = redirectUrl;
#             } else {
#                 if (giftNo && giftNo!='') {
#                     giftLayerHandler.open(giftNo);
#                 }
#             }
#         });
#     }
#
#     function directOrder(optionCnt, goodsNo, goodsSub, firstOptionCnt, giftNo) {
#         if($("[name=buy_list_opt_noprice]").length == 0) {
#             alert("옵션을 선택해 주세요.");
#             return false;
#         }
#
#         if (stateAll.pickupGoodsFlag === true) {
#             giftNo = 0;
#         }
#
#         if (giftNo) {
#             var info = $("#getgiftLayer .info");
#             var applyAmt = info.data('apply-amt');
#             var totalPrice = parseInt(unComma($(".sum-total-price > .price").html()));
#
#             var rate = (totalPrice && applyAmt) ? totalPrice / applyAmt * 100 : 0;
#
#             if (rate < 100) {
#                 info.find(".price > span").text([Comma(totalPrice), '원'].join(''));
#
#                 var progressbar = info.find('.progressbar-value');
#                 progressbar.attr('value', rate);
#                 progressbar.css('--value', rate + '%');
#                 uiLayerBasic('#getgiftLayer');
#                 return;
#             }
#         }
#         prepareOrder.order(optionCnt, goodsNo, goodsSub);
#     }
# </script>
# <div class="pop-add-cart"></div>
# <div class="ui-layer layer-basic gift_pop" id="layerGift">
# <div class="cart_pop"></div>
# <button class="ui-layer-close" onclick="giftLayerHandler.close(); return false;" type="button"><i class="ico ico-sm ico-close2">레이어 팝업 닫기</i></button>
# </div>
# <script type="text/javascript">
#     var giftSwiper = new Swiper('.product_list', {
#         slidesPerView:"auto",
#         observer :true,
#         observeParents:true,
#         pagination: {
#             el: '.gift-swiper-pagination',
#             type: 'fraction',
#         },
#         navigation: {
#             nextEl: '.gift-swiper-button-next',
#             prevEl: '.gift-swiper-button-prev',
#         }
#     });
#
#     // 장바구니 담기 시 Confirm -> Toast 변경
#     var cartTimer = null;
#     function addCartToast(optionCnt, goodsNo, goodsSub, shopNo = 1) {
#         if (cartTimer) {
#             clearTimeout(cartTimer);
#         }
#         cartTimer = setTimeout(function () {
#             if (isPickupSelected() && shopNo === 1) {
#                 if ($("[name=buy_list_opt_noprice]").length === 0) {
#                     alert("옵션을 선택해 주세요.");
#                     return false;
#                 }
#                 pickupOrder.showSelectPickupShopLayer(goodsNo, prepareOrder.makeSelectedOptionDataSet(), 'CART');
#                 return;
#             }
#             prepareOrder.addCart(optionCnt, goodsNo, goodsSub, function (response, msg, redirectUrl) {
#                 if (response === 1) {
#                     $('#select-purchase-Layer').removeClass('is-active');
#                     $('#duplicate_cart_toast').hide();
#                     $("#add_cart_toast").fadeIn(200).delay(2250).fadeOut(200);
#                     loadCartTotal();
#                 } else if (response === -27) {
#                     $('#select-purchase-Layer').removeClass('is-active');
#                     $('#add_cart_toast').hide();
#                     $("#duplicate_cart_toast").fadeIn(200).delay(2250).fadeOut(200);
#                 } else {
#                     alert(msg);
#                     if (redirectUrl) {
#                         document.location.href = redirectUrl;
#                     }
#                 }
#             }, shopNo);
#         }, 300);
#     }
# </script>
# <!-- [D]//사은품 적용상품 레이어 -->
# <!--매장 픽업 가이드-->
# <div class="ui-layer layer-basic layer-change-info layer-pickup-guide" id="layer-pickup-guide"></div>
# <!-- //[D] FE-4968 매장 픽업 -->
# <input name="shop_domain" type="hidden" value="www.musinsa.com"/>
# <form name="f1">
# <input name="popup" type="hidden"/>
# </form>
# <script src="//static.msscdn.net/skin/musinsa/js/product_v3.js?202303151041"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/relative_cart.js?202303081910"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/gift_suggestion.js?202003171511"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/image_zoom.js?20160119"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/reviews.comments.js?202209140001"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/reviews.sns.js?202011021242"></script>
# <script src="//static.msscdn.net/skin/m_musinsa/js/owl.carousel.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/1.0.2/Chart.min.js"></script><!-- chart.js -->
# <script src="//static.msscdn.net/skin/musinsa/js/kakao.min.js?20160204_1"></script><!-- 카카오톡 관련 소스 //-->
# <script src="//static.msscdn.net/skin/musinsa/js/kakao.api.js?20191031"></script>
# <script src="//static.msscdn.net/skin/js/goods/goods_detail.js?v=202303151041"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/goods/goods_detail.js?v=202303151041"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/goods/goods_detail_imagesearch.js?v=202303151041"></script>
# <script src="//static.msscdn.net/skin/js/goods/goods_detail_magazine.js?v=202303151041"></script>
# <script>
#
#     var goodsSimilarNo = !!stateAll.productInfo.similar_no ? stateAll.productInfo.similar_no : 0;
#
#     if ($("#goodsSimilarArea").length <= 0) {
#         goodsSimilarNo = 0;
#     }
#
#     var apiVersion = 'v2';
#     $.ajax({
#         type : 'GET',
#         url: GOODS_API_DOMAIN + '/' + apiVersion + '/review/list',
#         data : {
#             goodsNo: stateAll.productInfo.goods_no,
#             similarNo: goodsSimilarNo,
#             type: 'style',
#             itemCategoryCode: stateAll.productInfo.item_cat_cd
#         },
#         dataType : 'html',
#         success : function(fragment) {
#             $('#estimateBox').replaceWith(fragment);
#         },
#         error : function(error) {
#             console.log(error);
#         }
#     });
# </script>
# </body>
# </html>

# %%
#경로: #product_order_info > div.explan_product.product_info_section > ul > li:nth-child(1) > p.product_article_contents > strong

#품번은 \ 속에 묶여있다

#우선 순위별로 브랜드 이름만을 추출하기 위해 brand_list를 만드는데, li:nth-child(1)을 li로 바꾸면 첫페이지의 모든 브랜드 순위를 가져올 수 있다.

a=html_1.select('#product_order_info > div.explan_product.product_info_section > ul > li:nth-child(1) > p.product_article_contents > strong')
a[0].string, a[0].get_text()

# .string을 사용하면 None을 반환>>단순히 문자열이 없기 때문
# Out:
# (None, 'BROWNBREATH / BHWMHDB10AS')

# %%
# 그렇기 때문에 유니코드 형식으로 텍스트를 문자열도 반환하는 get_text()를 사용
part_num_html=html_1.select('#product_order_info > div.explan_product.product_info_section > ul > li:nth-child(1) > p.product_article_contents > strong')
part_num=part_num_html[0].get_text().split('/')[-1].strip()
part_num
# Out:
# 'BHWMHDB10AS'

# %%
#성별 가져오기
#경로: #product_order_info > div.explan_product.product_info_section > ul > li:nth-child(2) > p.product_article_contents > span.txt_gender

#남자와 여자에 대한 정보가 각각 다른 \으로 묶여 있다.

#즉, 남자 혼자, 여자 혼자, 남자와 여자 일때의 형태가 다를 수도 있으므로 규칙을 찾아야 한다.
a=html_1.select("#product_order_info > div.explan_product.product_info_section > ul > li:nth-child(2) > p.product_article_contents > span.txt_gender")
a[0].get_text()
# Out:
# '\n남\n여\n'

# %%
#서로 다른 성별 값을 가지고 있는 링크를 비교해보니, 성별 정보가 하나든 두개든 \n이 사이사이에 있다는 것을 알 수 있다. 그러므로 단순히 \n 값을 없애고, 양옆의 공백만 지워주면 충분할 것 같다! 또한 li:nth-child(2) 에서 3번째 child에 성별의 값이 들어가 있는 요소 또한 존재했다 고로 child를 특정하지 않고 li만 사용 해야 할 것 같다.

response_2=requests.get(link_list[2],headers=headers)
html_2=bs(response_2.text, 'lxml')
a2 = html_2.select("#product_order_info > div.explan_product.product_info_section > ul > li > p.product_article_contents > span.txt_gender")
a2[0].get_text().replace('\n',' ').strip()
# Out:
# '남'

# %%
sex_html=html_1.select("#product_order_info > div.explan_product.product_info_section > ul > li > p.product_article_contents > span.txt_gender")
sex=sex_html[0].get_text().replace('\n',' ').strip()
sex
# Out:
# '남 여'

# %%
#selenium으로 조회수 조회하기
#조회수, 누적판매, 좋아요 수 가져오기
#조회수 경로: #pageview_1m
#누적판매 경로: #sales_1y_qty
#좋아요 경로: #product-top-like > p.product_article_contents.goods_like_2524570 > span
#하지만 문제가 있다. 조회수, 누적 판매, 그리고 좋아요는 실시간으로 값이 바뀌는 동적 요소이다.
#bs4를 이용하여 위에서 데이터를 뽑아왔던 방법대로 이용해보아도 원하는 데이터가 뽑히지 않다는 것을 확인할 수 있었다. (계속 빈 리스트를 가져올 뿐이었다. 셀레니움을 사용해보기로 했다

# %%
from selenium import webdriver

# %%
#셀레니움을 설치해주었고, webdriver이라는 것을 가지고 왔다. 셀레니움은 처음 써보지만, 나의 버전과 맞는 chromedriver이라는 것을 다운받아 준 후 가상의 chrome 창을 열어 그 곳에서 원하는 데이터를 가지고 오는 것 같다.

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get(link_list[0])
sel_html=driver.page_source
html_2=bs(sel_html)

# %%
#빈리스트 가지고 오는 것 확인
html_2.select('pageview_1m')
# Out:
# []

# %%
#find_all을 사용하니 문제 해결!
html_2.find_all("strong", {"id":"pageview_1m"})
# Out:
# [<strong id="pageview_1m">17.2만 회 이상</strong>]

# %%
#3.3만회 이상 텍스트 뽑아오기
view_html=html_2.find_all("strong", {"id":"pageview_1m"})
view=view_html[0].get_text()
view
# Out:
# '17.2만 회 이상'

# %%
# 누적 판매와 좋아요 추출 하기

#누적판매
sales_html=html_2.find_all("strong", {"id":"sales_1y_qty"})
sales=sales_html[0].get_text()
sales
# Out:
# '9.2만 개 이상'

# %%
#좋아요
like_html=html_2.find_all("span", {"class": "prd_like_cnt"})
like=like_html[0].get_text()
like
# Out:
# '82,175'

# %%
#드라이버 닫기
driver.close()
