# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import time
from tqdm import tqdm

# %%
url="https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax="

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 pd.read_html(url)
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:939, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     937 else:
#     938     assert retained is not None  # for mypy
# --> 939     raise retained
#     941 ret = []
#     942 for table in tables:
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\users\jpc10\ideaprojects\untitled\venv\lib\site-packages\pandas\io\html.py:569, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     566 tables = doc.find_all(element_name, attrs=attrs)
#     568 if not tables:
# --> 569     raise ValueError("No tables found")
#     571 result = []
#     572 unique_tables = set()
#
# ValueError: No tables found

# %%
response=requests.get(url)
response.status_code
# Out:
# 200

# %%
html=bs(response.text, 'lxml')
html
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title>상품 랭킹 | 무신사 스토어</title>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.
# 무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다." name="description"/>
# <script type="text/javascript">
#             var THIS_PAGE_GF = 'A';
#         </script>
# <link href="https://image.msscdn.net/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="648837775133366" id="fbAddId" property="fb:app_id"/>
# <meta content="website" id="fbOgType" property="og:type"/>
# <meta content="상품 랭킹 | 무신사 스토어" id="fbOgTitle" property="og:title"/>
# <meta content="https://image.msscdn.net/mfile_s01/fb/share_musinsa.png" id="fbOgImage" property="og:image"/>
# <meta content="무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.
# 무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다." id="fbOgDescription" property="og:description"/>
# <meta content="https://www.musinsa.com/ranking/best?period=now&amp;age=ALL&amp;mainCategory=001&amp;subCategory=&amp;leafCategory=&amp;price=&amp;golf=false&amp;kids=false&amp;newProduct=false&amp;exclusive=false&amp;discount=false&amp;soldOut=false&amp;page=1&amp;viewType=small&amp;priceMin=&amp;priceMax=&amp;_gf=A" id="fbOgUrl" property="og:url"/>
# <link href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/store_common.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/style.min.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/sub.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/media_query.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/new.css?202302272038" rel="stylesheet" type="text/css"/>
# <!-- 검색페이지에서 사용 -->
# <!-- Swiper -->
# <link href="//static.msscdn.net/swiper/swiper.min.css" rel="stylesheet" type="text/css"/>
# <!--jqModal-->
# <link href="//static.msscdn.net/skin/musinsa/css/jqModal.css?202302272038" rel="stylesheet" type="text/css"/>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/skin/musinsa/css/image_search.css?202302272038" rel="stylesheet" type="text/css"/>
# <!-- //유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/static/common/1.2.0/pc.css?202302272038" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/mfile_scr/layouts/community/css/musinsa_timeline.css?version=6.249" rel="stylesheet" type="text/css"/>
# <!-- 공통 레이아웃에서 사용함 -->
# <link href="//static.msscdn.net/ui/build/pc/css/common.css" rel="stylesheet" type="text/css"/>
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/base.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/common.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?202302272038" type="text/javascript"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/layout/common.js" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/ui.js?202302272038" type="text/javascript"></script>
# <!-- Swiper -->
# <script src="//static.msscdn.net/swiper/swiper.min.js"></script>
# <!--jqModal-->
# <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?202302272038" type="text/javascript"></script>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/search/image_search.js" type="text/javascript"></script>
# <script type="text/javascript">
#         $(document).ready(function(){
#             if (window.image_search) {
#                 window.image_search.setUrl('https://www.musinsa.com');
#             }
#         });
#     </script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?202302272038" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/common/1.2.0/chunk-vendors.js"></script>
# <script href="//static.msscdn.net/layouts/community/js/musinsa_timeline.new.js?version=6.249" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/lib/blackhole/1.1.0/mssBlackholeSdk.js?202302272038"></script>
# <script>
#         var dataLayer = dataLayer || [];
#         dataLayer.push({
#             "productList" : {
#                 "email": "",
#                 // 조회 결과 중 상위 3개를 셋팅함. (goods_no-goods_sub)
#                 "list": []
#             }
#         });
#     </script>
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/layout/config.js" type="text/javascript"></script>
# <script>
#         var uiConfig = {
#             service : 'mensinsa',
#             isWusinsaService : false,
#             htmlTitle : '상품 랭킹 | 무신사 스토어',
#             isLoginYn: 'N',
#             memberGroupNo: '0',
#             total: '',
#             siteCode: 'mensinsa',
#             headerSex: '',
#             globalFilter: 'A',
#             globalFilterWrapperCssName: 'musinsa',
#
#             searchFrontServiceUrl: 'https://www.musinsa.com/search/musinsa/',
#             searchFrontUrl: 'https://www.musinsa.com',
#             searchApiUrl: 'https://search.musinsa.com',
#             serviceUrl : 'https://www.musinsa.com',
#             magazineUrl : 'https://magazine.musinsa.com',
#             storeUrl: 'https://www.musinsa.com',
#             mobileStoreUrl: 'https://www.musinsa.com',
#             wusinsaUrl : 'https://wusinsa.musinsa.com',
#             myPageFrontUrl: 'https://www.musinsa.com',
#
#             likeApiUrl : 'https://like.musinsa.com/like',
#             goodsDetailUrl: '/app/goods/',
#             brandShopUrl: 'https://www.musinsa.com/brands/',
#
#             cssResourceUrl : '//static.msscdn.net',
#             httpImageResourceUrl : 'https://image.msscdn.net',
#             imageResourceUrl : 'https://image.msscdn.net',
#             staticResourceUrl : '//static.msscdn.net',
#             staticResourceVersion : '202302272038',
#
#             noImagePrefix: 'no_image_'
#         };
#
#         mss.ui.config.set(uiConfig);
#
#     </script>
# <!-- mss.ui : global config end -->
# <!-- mss.ui : gnb start -->
# <script src="//static.msscdn.net/static/search/202302272038/js/ajax.js" type="text/javascript"></script>
# </head>
# <body>
# <script>
#         var siteCode = "mensinsa";
#
#         mss.ui.left = {
#             category: {
#                 dCatCd: "", // 선택된 카테고리 코드
#             },
#             menuType: 'list'
#         };
#
#         mss.ui.loggedIn = mss.ui.config.get().isLoginYn === 'Y';
#
#     </script>
# <div id="topCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/pc.js"></script>
# <div class="wrap">
# <div id="leftCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/lnb.js?202302272038"></script>
# <div class="right_area page-contents-best">
# <input name="d_cat_cd" type="hidden" value=""/>
# <div class="pagenation">
# <div class="nav_sub">
# <a href="https://www.musinsa.com">무신사 스토어</a>
# <span class="icon_entity">&gt;</span>
# <span>상품 랭킹</span>
# </div>
# <span class="txt_selected_division">all</span>
# </div>
# <div class="page_box">
# <div class="title_box">
# <h2 class="title-page">Ranking Shop</h2>
# <div class="tool-tabBtn">
# <a class="plain-btn btn active" href="https://www.musinsa.com/app/contents/bestranking">
#                                 상품
#                             </a><a class="plain-btn btn" href="https://www.musinsa.com/app/usr/brand_rank">
#                                 브랜드
#                             </a><a class="plain-btn btn" href="https://www.musinsa.com/app/usr/search_ranking">
#                                 검색어
#                             </a>
# </div>
# </div>
# <div class="page_intro">무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.<br/>무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다.</div>
# </div>
# <div class="n-banner-ranking">
# <a href="https://www.musinsa.com/app/cs/faq?q=%EB%9E%AD%ED%82%B9">
#                         무신사 랭킹을 알려드립니다.
#                         <em>
#                             자세히 보기
#                         </em>
# </a>
# </div>
# <form id="goodsRankForm">
# <div class="clear">
# <input name="period" type="hidden" value="now"/>
# <input name="age" type="hidden" value="ALL"/>
# <input name="mainCategory" type="hidden" value="001"/>
# <input name="subCategory" type="hidden" value=""/>
# <input name="leafCategory" type="hidden" value=""/>
# <input name="price" type="hidden" value=""/>
# <input name="golf" type="hidden" value="false"/>
# <input name="kids" type="hidden" value="false"/>
# <input name="newProduct" type="hidden" value="false"/>
# <input name="exclusive" type="hidden" value="false"/>
# <input name="discount" type="hidden" value="false"/>
# <input name="soldOut" type="hidden" value="false"/>
# <input name="page" type="hidden" value="1"/>
# <input name="viewType" type="hidden" value="small"/>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             기간 구분
#         </p>
# <dl class="list_division_brand">
# <dt></dt>
# <dd>
# <ul class="division_reset">
# <li class="selected">
# <a href="javascript:mss.ranking.goods.filter.period('now');">실시간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('day');">일간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('week');">주간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('month');">월간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('month_3');">3개월</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             대분류
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div>
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_reset">
# <li class="selected">
# <a href="javascript:mss.ranking.goods.filter.mainCategory('001');">상의</a>
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
# <span class="delete-btn-red">
#                                 X
#                             </span>
# </a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('002');">아우터</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('003');">바지</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('020');">원피스</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('022');">스커트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('018');">스니커즈</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('005');">신발</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('004');">가방</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('054');">여성 가방</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('017');">스포츠/용품</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('007');">모자</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('008');">양말/레그웨어</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('026');">속옷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('009');">선글라스/안경테</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('011');">액세서리</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('006');">시계</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('025');">주얼리</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('015');">뷰티</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('012');">디지털/테크</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('058');">리빙</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('014');">컬처</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('021');">반려동물</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             중분류
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div class="selected">
# <a href="javascript:mss.ranking.goods.filter.subCategory(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001006');">니트/스웨터</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001004');">후드 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001005');">맨투맨/스웨트셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001010');">긴소매 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001002');">셔츠/블라우스</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001003');">피케/카라 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001001');">반소매 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001011');">민소매 티셔츠</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('001008');">기타 상의</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_price box_division_group">
# <p class="article_title">
#             가격
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div class="selected">
# <a href="javascript:mss.ranking.goods.filter.price(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_price division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('~50000');">5만원 이하</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('50000~100000');">5~10만원</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('100000~200000');">10~20만원</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('200000~300000');">20~30만원</a>
# </li>
# <li class="last">
# <a href="javascript:mss.ranking.goods.filter.price('300000~');">30만원 이상</a>
# </li>
# <li class="division_search_box search_price">
# <input class="division_search_input" maxlength="9" name="priceMin" title="최소 가격 검색" type="text" value=""/><span>원 ~</span>
# <input class="division_search_input" maxlength="9" name="priceMax" title="최대 가격 검색" type="text" value=""/><span>원</span>
# <span class="division_search_btn" onclick="mss.ranking.goods.filter.customPrice();">검색</span>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# </div>
# <div class="right_contents hover_box">
# <div class="select_option">
# <span class="keyword_selected">
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
#             대분류 : 상의
#             <span class="delete-btn-red">X</span>
# </a>
# </span>
# </div>
# <div class="boxed-list-wrapper rank-shop">
# <div class="sorter-box box">
# <p class="box_renew">
#                         7분 전 갱신
#                     </p>
# <div class="pagination">
# <div class="wrapper">
# <a class="fa fa-angle-double-left paging-btn btn first" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">첫 페이지</label>
# </a>
# <a class="fa fa-angle-left paging-btn btn prev" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">이전</label>
# </a>
# <a class="paging-btn btn active" href="javascript:mss.ranking.goods.page(1);">1</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(2);">2</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(3);">3</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(4);">4</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(5);">5</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(6);">6</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(7);">7</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(8);">8</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(9);">9</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(10);">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:mss.ranking.goods.page(11);">
# <label style="display:none">다음</label>
# </a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:mss.ranking.goods.page(100);">
# <label style="display:none">마지막 페이지</label>
# </a>
# </div>
# </div>
# </div>
# <div class="thumbType_box box">
# <span class="image_view_select">
# <a class="view_select_small selected" href="javascript:mss.ranking.goods.viewType('small');" title="작은 이미지">
#                             작은 이미지
#                         </a>
# <a class="view_select_big" href="javascript:mss.ranking.goods.viewType('large');" title="큰 이미지">
#                             큰 이미지
#                         </a>
# </span>
# <span class="counter check_box_area">
# <label><input alt="요즘 신상" autocomplete="off" onchange="mss.ranking.goods.filter.check('newProduct', this.checked);" type="checkbox" value="false"/>🔥 NEW</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('exclusive', this.checked);" type="checkbox" value="false"/>단독</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('discount', this.checked);" type="checkbox" value="false"/>세일</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('soldOut', this.checked);" type="checkbox" value="false"/>품절 포함</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('golf', this.checked);" type="checkbox" value="false"/>골프</label>
# </span>
# <span class="counter check_box_area">
# <label><input autocomplete="off" onchange="mss.ranking.goods.filter.check('kids', this.checked);" type="checkbox" value="false"/>키즈</label>
# </span>
# <span class="counter box_num_goods">
# <label class="is_goods">상품 수 : 169,205개</label>
# </span>
# <span class="pagingNumber">
# <span class="totalPagingNum">100</span>
#         페이지 중
#         <span class="currentPagingNum">1</span>
#         페이지
#
# </span>
# </div>
# <div class="list-box box">
# <ul class="snap-article-list boxed-article-list article-list center list goods_small_media8" id="goodsRankList">
# <li class="li_box" data-goods-no="2126149">
# <p class="n-label label-default txt_num_rank">
#             1위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2126149?loc=goods_rank">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 플랫 테리 오버사이즈 스트링 스웨트셔츠 [블랙]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210913/2126149/2126149_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/musinsastandard">무신사 스탠다드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2126149?loc=goods_rank" title="플랫 테리 오버사이즈 스트링 스웨트셔츠 [블랙]">
#
#
#
#
#                         플랫 테리 오버사이즈 스트링 스웨트셔츠 [블랙]
#                     </a>
# </p>
# <p class="price">
# <del>39,900원</del>
#                     35,890원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2126149', '2126149', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2126149" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2126149', '2126149', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">35,890원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">1,029</span>
# </p>
# <p class="txt_cnt_like goods_like_2126149 hide" id="like_2126149">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2126149" onclick="viewOption3(this, '2126149', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2126149" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3011271">
# <p class="n-label label-default txt_num_rank">
#             2위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3011271?loc=goods_rank">
# <img alt="코드그라피(CODEGRAPHY) 24H 트랙 브이넥 맨투맨_멜란지그레이" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230109/3011271/3011271_16777113044033_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/codegraphy">코드그라피</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3011271?loc=goods_rank" title="24H 트랙 브이넥 맨투맨_멜란지그레이">
# <strong class="txt_reserve">3 / 30 배송</strong>
#
#                         24H 트랙 브이넥 맨투맨_멜란지그레이
#                     </a>
# </p>
# <p class="price">
# <del>49,000원</del>
#                     44,100원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-9,702원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3011271', '3011271', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3011271" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3011271', '3011271', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">44,100원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">22</span>
# </p>
# <p class="txt_cnt_like goods_like_3011271 hide" id="like_3011271">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3011271" onclick="viewOption3(this, '3011271', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3011271" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2326935">
# <p class="n-label label-default txt_num_rank">
#             3위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2326935?loc=goods_rank">
# <img alt="예일(YALE) (23SS) 2 TONE ARCH HOODIE GRAY" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220125/2326935/2326935_11_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/yale">예일</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2326935?loc=goods_rank" title="(23SS) 2 TONE ARCH HOODIE GRAY">
#
#
#
#
#                         (23SS) 2 TONE ARCH HOODIE GRAY
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     55,300원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-5,530원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2326935', '2326935', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2326935" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2326935', '2326935', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">55,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">12,453</span>
# </p>
# <p class="txt_cnt_like goods_like_2326935 hide" id="like_2326935">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2326935" onclick="viewOption3(this, '2326935', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2326935" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2684320">
# <p class="n-label label-default txt_num_rank">
#             4위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2684320?loc=goods_rank">
# <img alt="노매뉴얼(NOMANUAL) MRI HOODIE - BLACK" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220727/2684320/2684320_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/nomanual">노매뉴얼</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2684320?loc=goods_rank" title="MRI HOODIE - BLACK">
#
#
#
#
#                         MRI HOODIE - BLACK
#                     </a>
# </p>
# <p class="price">
# <del>96,000원</del>
#                     86,400원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-4,320원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2684320', '2684320', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2684320" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2684320', '2684320', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">86,400원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">697</span>
# </p>
# <p class="txt_cnt_like goods_like_2684320 hide" id="like_2684320">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2684320" onclick="viewOption3(this, '2684320', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2684320" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3012570">
# <p class="n-label label-default txt_num_rank">
#             5위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3012570?loc=goods_rank">
# <img alt="트래블(TRAVEL) 워크샵 디비전 피그먼트 후드티 블랙 차콜" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230110/3012570/3012570_16765978037622_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/travel">트래블</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3012570?loc=goods_rank" title="워크샵 디비전 피그먼트 후드티 블랙 차콜">
#
#
#
#
#                         워크샵 디비전 피그먼트 후드티 블랙 차콜
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     44,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3012570', '3012570', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3012570" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3012570', '3012570', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">44,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">94</span>
# </p>
# <p class="txt_cnt_like goods_like_3012570 hide" id="like_3012570">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3012570" onclick="viewOption3(this, '3012570', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3012570" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2744785">
# <p class="n-label label-default txt_num_rank">
#             6위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-reverse label-boutique">부티크</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2744785?loc=goods_rank">
# <img alt="메종 마르지엘라(MAISON MARGIELA) 남성 백 4 스티치 엘보 패치 니트 - 네이비 / SI1GP0001S18064511F" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220826/2744785/2744785_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/maisonmargiela">메종 마르지엘라</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2744785?loc=goods_rank" title="남성 백 4 스티치 엘보 패치 니트 - 네이비 / SI1GP0001S18064511F">
# <strong class="txt_reserve">새벽배송</strong>
#                         남성 백 4 스티치 엘보 패치 니트 - 네이비 / SI1GP0001S18064511F
#                     </a>
# </p>
# <p class="price">
#
#                     1,328,000원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-30,000원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2744785', '2744785', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2744785" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2744785', '2744785', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">1,328,000원</span>
# </li>
# </ul>
# </div>
# <p class="txt_cnt_like goods_like_2744785 hide" id="like_2744785">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2744785" onclick="viewOption3(this, '2744785', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2744785" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3012625">
# <p class="n-label label-default txt_num_rank">
#             7위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3012625?loc=goods_rank">
# <img alt="트래블(TRAVEL) 리즌 트레일 피그먼트 후드티 상그리아 레드" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230110/3012625/3012625_16765975095633_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/travel">트래블</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3012625?loc=goods_rank" title="리즌 트레일 피그먼트 후드티 상그리아 레드">
# <strong class="txt_reserve">3 / 15 배송</strong>
#
#                         리즌 트레일 피그먼트 후드티 상그리아 레드
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     44,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3012625', '3012625', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3012625" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3012625', '3012625', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">44,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">27</span>
# </p>
# <p class="txt_cnt_like goods_like_3012625 hide" id="like_3012625">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3012625" onclick="viewOption3(this, '3012625', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3012625" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2122566">
# <p class="n-label label-default txt_num_rank">
#             8위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2122566?loc=goods_rank">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 레이어드 크루 넥 반팔 티셔츠_일반 기장 2팩" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210910/2122566/2122566_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/musinsastandard">무신사 스탠다드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2122566?loc=goods_rank" title="레이어드 크루 넥 반팔 티셔츠_일반 기장 2팩">
#
#
#
#
#                         레이어드 크루 넥 반팔 티셔츠_일반 기장 2팩
#                     </a>
# </p>
# <p class="price">
#
#                     33,800원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-6,760원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2122566', '2122566', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2122566" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2122566', '2122566', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">33,800원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">13,955</span>
# </p>
# <p class="txt_cnt_like goods_like_2122566 hide" id="like_2122566">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2122566" onclick="viewOption3(this, '2122566', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2122566" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1574201">
# <p class="n-label label-default txt_num_rank">
#             9위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1574201?loc=goods_rank">
# <img alt="브라운브레스(BROWNBREATH) TAG HOODIE - ASH" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200901/1574201/1574201_16735742721712_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/brownbreath">브라운브레스</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1574201?loc=goods_rank" title="TAG HOODIE - ASH">
#
#
#
#
#                         TAG HOODIE - ASH
#                     </a>
# </p>
# <p class="price">
#
#                     79,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1574201', '1574201', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1574201" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1574201', '1574201', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">79,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">4,470</span>
# </p>
# <p class="txt_cnt_like goods_like_1574201 hide" id="like_1574201">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1574201" onclick="viewOption3(this, '1574201', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1574201" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1706633">
# <p class="n-label label-default txt_num_rank">
#             10위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/1706633?loc=goods_rank">
# <img alt="폴로 랄프 로렌(POLO RALPH LAUREN) 커스텀핏 옥스포드 셔츠 - 화이트" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20201130/1706633/1706633_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/poloralphlauren">폴로 랄프 로렌</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/1706633?loc=goods_rank" title="커스텀핏 옥스포드 셔츠 - 화이트">
#
#
#
#
#                         커스텀핏 옥스포드 셔츠 - 화이트
#                     </a>
# </p>
# <p class="price">
#
#                     199,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1706633', '1706633', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1706633" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1706633', '1706633', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">199,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">2,313</span>
# </p>
# <p class="txt_cnt_like goods_like_1706633 hide" id="like_1706633">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1706633" onclick="viewOption3(this, '1706633', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1706633" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3034895">
# <p class="n-label label-default txt_num_rank">
#             11위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3034895?loc=goods_rank">
# <img alt="스컬프터(SCULPTOR) Velour Soccer Jersey Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230119/3034895/3034895_16752250753178_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/sculptor">스컬프터</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3034895?loc=goods_rank" title="Velour Soccer Jersey Black">
#
#
#
#
#                         Velour Soccer Jersey Black
#                     </a>
# </p>
# <p class="price">
# <del>119,000원</del>
#                     107,100원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3034895', '3034895', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3034895" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3034895', '3034895', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">107,100원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 98.0%"></span>
# </span>
# <span class="count">202</span>
# </p>
# <p class="txt_cnt_like goods_like_3034895 hide" id="like_3034895">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3034895" onclick="viewOption3(this, '3034895', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3034895" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2038497">
# <p class="n-label label-default txt_num_rank">
#             12위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2038497?loc=goods_rank">
# <img alt="라퍼지스토어(LAFUDGESTORE) [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Midnight Blue" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210722/2038497/2038497_5_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/lafudgestore">라퍼지스토어</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2038497?loc=goods_rank" title="[SS Ver.]헤비 코튼 오버 럭비 맨투맨_Midnight Blue">
#
#
#
#
#                         [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Midnight Blue
#                     </a>
# </p>
# <p class="price">
# <del>45,000원</del>
#                     39,000원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-3,900원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2038497', '2038497', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2038497" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2038497', '2038497', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">39,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">15,771</span>
# </p>
# <p class="txt_cnt_like goods_like_2038497 hide" id="like_2038497">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2038497" onclick="viewOption3(this, '2038497', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2038497" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2313388">
# <p class="n-label label-default txt_num_rank">
#             13위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# ...
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/mardimercredi">마르디 메크르디</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2453552?loc=goods_rank" title="TSHIRT FLOWERMARDI_BLACK CREAM">
# <strong class="txt_reserve">3 / 13 배송</strong>
#
#                         TSHIRT FLOWERMARDI_BLACK CREAM
#                     </a>
# </p>
# <p class="price">
# <del>42,000원</del>
#                     39,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2453552', '2453552', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2453552" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2453552', '2453552', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">39,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">2,804</span>
# </p>
# <p class="txt_cnt_like goods_like_2453552 hide" id="like_2453552">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2453552" onclick="viewOption3(this, '2453552', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2453552" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2827512">
# <p class="n-label label-default txt_num_rank">
#             86위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2827512?loc=goods_rank">
# <img alt="굿라이프웍스(GLW) 오버핏 소프트 레글런 스웨터 니트 내츄럴그린" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220929/2827512/2827512_16747843321702_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/goodlifeworks">굿라이프웍스</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2827512?loc=goods_rank" title="오버핏 소프트 레글런 스웨터 니트 내츄럴그린">
#
#
#
#
#                         오버핏 소프트 레글런 스웨터 니트 내츄럴그린
#                     </a>
# </p>
# <p class="price">
# <del>62,000원</del>
#                     49,800원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-4,980원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2827512', '2827512', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2827512" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2827512', '2827512', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">49,800원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 98.0%"></span>
# </span>
# <span class="count">696</span>
# </p>
# <p class="txt_cnt_like goods_like_2827512 hide" id="like_2827512">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2827512" onclick="viewOption3(this, '2827512', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2827512" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2339310">
# <p class="n-label label-default txt_num_rank">
#             87위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2339310?loc=goods_rank">
# <img alt="드로우핏(DRAW FIT) 오버사이즈 집업 카라 터틀넥 니트 [NAVY]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220203/2339310/2339310_16747011853939_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/drawfit">드로우핏</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2339310?loc=goods_rank" title="오버사이즈 집업 카라 터틀넥 니트 [NAVY]">
#
#
#
#
#                         오버사이즈 집업 카라 터틀넥 니트 [NAVY]
#                     </a>
# </p>
# <p class="price">
# <del>76,000원</del>
#                     68,400원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-6,840원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2339310', '2339310', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2339310" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2339310', '2339310', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">68,400원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">1,082</span>
# </p>
# <p class="txt_cnt_like goods_like_2339310 hide" id="like_2339310">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2339310" onclick="viewOption3(this, '2339310', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2339310" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2733940">
# <p class="n-label label-default txt_num_rank">
#             88위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2733940?loc=goods_rank">
# <img alt="로라로라(ROLAROLA) COLLAR STRIPE BOARDER KNIT WH+BK" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20220823/2733940/2733940_5_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/rolarola">로라로라</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2733940?loc=goods_rank" title="COLLAR STRIPE BOARDER KNIT WH+BK">
#
#
#
#
#                         COLLAR STRIPE BOARDER KNIT WH+BK
#                     </a>
# </p>
# <p class="price">
# <del>79,000원</del>
#                     75,050원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-3,753원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2733940', '2733940', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2733940" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2733940', '2733940', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">75,050원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">1,796</span>
# </p>
# <p class="txt_cnt_like goods_like_2733940 hide" id="like_2733940">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2733940" onclick="viewOption3(this, '2733940', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2733940" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2285999">
# <p class="n-label label-default txt_num_rank">
#             89위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/2285999?loc=goods_rank">
# <img alt="필루미네이트(FILLUMINATE) 오버핏 아치 로고 스웨트 셔츠-오트밀" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20211229/2285999/2285999_3_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/filluminate">필루미네이트</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/2285999?loc=goods_rank" title="오버핏 아치 로고 스웨트 셔츠-오트밀">
#
#
#
#
#                         오버핏 아치 로고 스웨트 셔츠-오트밀
#                     </a>
# </p>
# <p class="price">
# <del>54,000원</del>
#                     39,900원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-3,990원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2285999', '2285999', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2285999" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2285999', '2285999', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">39,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">1,252</span>
# </p>
# <p class="txt_cnt_like goods_like_2285999 hide" id="like_2285999">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2285999" onclick="viewOption3(this, '2285999', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2285999" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="3007774">
# <p class="n-label label-default txt_num_rank">
#             90위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://www.musinsa.com/app/goods/3007774?loc=goods_rank">
# <img alt="마하그리드(MAHAGRID) DON’T PANIC PIGMENT SWEATSHIRT PINK(MG2DSMM441A)" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20230105/3007774/3007774_16746128102774_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/mahagrid">마하그리드</a>
# </p>
# <p class="list_info">
# <a href="https://www.musinsa.com/app/goods/3007774?loc=goods_rank" title="DON’T PANIC PIGMENT SWEATSHIRT PINK(MG2DSMM441A)">
# <strong class="txt_reserve">3 / 16 배송</strong>
#
#                         DON’T PANIC PIGMENT SWEATSHIRT PINK(MG2DSMM441A)
#                     </a>
# </p>
# <p class="price">
# <del>74,000원</del>
#                     59,200원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_3007774', '3007774', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_3007774" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_3007774', '3007774', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">59,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">265</span>
# </p>
# <p class="txt_cnt_like goods_like_3007774 hide" id="like_3007774">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol3007774" onclick="viewOption3(this, '3007774', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol3007774" style="display:none;"></div>
# </div>
# </li>
# </ul>
# </div>
# <div class="pagingNumber-box box">
# <span class="pagingNumber">
# <span class="totalPagingNum">100</span>
#         페이지 중
#         <span class="currentPagingNum">1</span>
#         페이지
#
# </span>
# </div>
# <div class="pagination-box box">
# <div class="pagination bottom">
# <div class="wrapper">
# <a class="fa fa-angle-double-left paging-btn btn first" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">첫 페이지</label>
# </a>
# <a class="fa fa-angle-left paging-btn btn prev" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">이전</label>
# </a>
# <a class="paging-btn btn active" href="javascript:mss.ranking.goods.page(1);">1</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(2);">2</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(3);">3</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(4);">4</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(5);">5</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(6);">6</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(7);">7</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(8);">8</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(9);">9</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(10);">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:mss.ranking.goods.page(11);">
# <label style="display:none">다음</label>
# </a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:mss.ranking.goods.page(100);">
# <label style="display:none">마지막 페이지</label>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# <script src="//static.msscdn.net/static/search/202302272038/js/common/pc/contents/goods.js" type="text/javascript"></script>
# <div class="ui-layer-close fixed"></div>
# <meta content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" name="google-site-verification"/>
# <div id="footerCommonPc"></div>
# <div class="ui-layer-close fixed"></div>
# </div>
# </div>
# </body>
# <script>
#         $(function() {
#             removeGfParameter();
#             $('img.lazyload').lazyload();
#         });
#     </script>
# <script src="//static.msscdn.net/static/search/202302272038/js/ranking/goods_pc.js" type="text/javascript"></script>
# </html>

# %%
brand_html=html.select('#goodsRankList > li > div.li_inner > div.article_info > p.item_title > a')
brand_html[0].string
# Out:
# '무신사 스탠다드'

# %%
brand_list=[]
for i in brand_html:
    brand_list.append(i.string)
brand_list[0:5]
# Out:
# ['무신사 스탠다드', '코드그라피', '예일', '노매뉴얼', '트래블']

# %%
html.select('#goodsRankList > li:nth-child(1) > div.li_inner > div.article_info > p.list_info > a')
# Out:
# [<a href="https://www.musinsa.com/app/goods/2126149?loc=goods_rank" title="플랫 테리 오버사이즈 스트링 스웨트셔츠 [블랙]">
#
#
#
#
#                          플랫 테리 오버사이즈 스트링 스웨트셔츠 [블랙]
#                      </a>]

# %%
a=html.select('#goodsRankList > li:nth-child(1) > div.li_inner > div.article_info > p.list_info > a')
a[0]['href']
# Out:
# 'https://www.musinsa.com/app/goods/2126149?loc=goods_rank'

# %%
link_name_html=html.select('#goodsRankList > li > div.li_inner > div.article_info > p.list_info > a')
link_list=[]
name_list=[]
for i in link_name_html:
    link_list.append(i['href'])
    name_list.append(i['title'])
link_list[0:5], name_list[0:5]
# Out:
# (['https://www.musinsa.com/app/goods/2126149?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/3011271?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/2326935?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/2684320?loc=goods_rank',
#   'https://www.musinsa.com/app/goods/3012570?loc=goods_rank'],
#  ['플랫 테리 오버사이즈 스트링 스웨트셔츠 [블랙]',
#   '24H 트랙 브이넥 맨투맨_멜란지그레이',
#   '(23SS) 2 TONE ARCH HOODIE GRAY',
#   'MRI HOODIE - BLACK',
#   '워크샵 디비전 피그먼트 후드티 블랙 차콜'])

# %%
rank_html=html.select('#goodsRankList > li > p')
rank_no_list=[]
for i in rank_html:
    rank_no_list.append(i.string.strip())
rank_no_list[0:5]
# Out:
# ['1위', '2위', '3위', '4위', '5위']

# %%
import selenium
from selenium import webdriver as wd
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests

from itertools import repeat
import re

# %%
url = 'https://www.musinsa.com/brands/musinsastandard?category3DepthCodes=&category2DepthCodes=&category1DepthCode=&colorCodes=&startPrice=&endPrice=&exclusiveYn=&includeSoldOut=&saleGoods=&timeSale=&includeKeywords=&sortCode=emt_high&tags=&page=1&size=90&listViewType=small&campaignCode=&groupSale=&outletGoods=false&boutiqueGoods='
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# soup에 해당 url 페이지의 parsing된 html 정보 모두 담기게 됨"

# %%
soup.find_all('a', attrs={'class':'img-block'})
# Out:
# [<a class="img-block" href="//www.musinsa.com/app/goods/1220731" name="goods_link" title="사피아노 신세틱 레더 벨트">
#  <img alt="무신사 스탠다드(MUSINSA STANDARD) 사피아노 신세틱 레더 벨트" class="lazyload lazy" data-original="//image.msscdn.net/images/goods_img/20191112/1220731/1220731_3_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
#  </a>,
#  <a class="img-block" href="//www.musinsa.com/app/goods/1149328" name="goods_link" title="테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]">
#  <img alt="무신사 스탠다드(MUSINSA STANDARD) 테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]" class="lazyload lazy" data-original="//image.msscdn.net/images/goods_img/20190910/1149328/1149328_16760172322551_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
#  </a>,
#  <a class="img-block" href="//www.musinsa.com/app/goods/
125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
#  </a>,
#  <a class="img-block" href="//www.musinsa.com/app/goods/912315" name="goods_link" title="다운 푸퍼 숏 패딩 재킷 [라이트 그레이]">
#  <img alt="무신사 스탠다드(MUSINSA STANDARD) 다운 푸퍼 숏 패딩 재킷 [라이트 그레이]" class="lazyload lazy" data-original="//image.msscdn.net/images/goods_img/20181123/912315/912315_6_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
#  </a>,
#  <a class="img-block" href="//www.musinsa.com/app/goods/1417692" name="goods_link" title="우먼즈 베이식 크루 넥 반팔 티셔츠 [블랙]">
#  <img alt="무신사 스탠다드(MUSINSA STANDARD) 우먼즈 베이식 크루 넥 반팔 티셔츠 [블랙]" class="lazyload lazy" data-original="//image.msscdn.net/images/goods_img/20200423/1417692/1417692_2_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>
#  </a>]

# %%
soup.find_all('a', attrs={'class':'img-block'})[0]['href'] # url
soup.find_all('a', attrs={'class':'img-block'})[0]['title'] # 상품제목
# Out:
# '사피아노 신세틱 레더 벨트'

# %%
soup.find_all('p', attrs={'class':'price'})[0].get_text()
# Out:
# '\n                   15,900원\n                  \n                '

# %%
soup.find_all('p', attrs={'class':'price'})[0].get_text().split()[0]
# Out:
# '15,900원'

# %%
[re.sub(r'[^0-9]', '', soup.get_text().split()[0]) for soup in soup.find_all('p', attrs={'class':'price'})]
# Out:
# ['15900',
#  '39900',
#  '39900',
#  '15900',
#  '41900',
#  '18900',
#  '21900',
#  '19900',
#  '41900',
#  '79900',
#  '16900',
#  '15900',
#  '18900',
#  '49900',
#  '16900',
#  '81900',
#  '37800',
#  '19900',
#  '15900',
#  '22900',
#  '27900',
#  '83900',
#  '13900',
#  '23900',
#  '24900',
#  '39900',
#  '31900',
#  '159900',
#  '29900',
#  '31900',
#  '43900',
#  '22900',
#  '15900',
#  '19900',
#  '13900',
#  '16900',
#  '43900',
#  '33900',
#  '31800',
#  '33900',
#  '39900',
#  '39900',
#  '24900',
#  '39900',
#  '33800',
#  '39900',
#  '33900',
#  '13900',
#  '79900',
#  '41900',
#  '41900',
#  '31900',
#  '19900',
#  '13900',
#  '19900',
#  '16900',
#  '19900',
#  '39900',
#  '49900',
#  '19900',
#  '49900',
#  '43900',
#  '27900',
#  '33900',
#  '53900',
#  '31900',
#  '39900',
#  '16900',
#  '39900',
#  '29900',
#  '29900',
#  '41900',
#  '49900',
#  '11900',
#  '119900',
#  '39900',
#  '19900',
#  '49900',
#  '39800',
#  '13900',
#  '49900',
#  '18900',
#  '26900',
#  '20900',
#  '16900',
#  '22900',
#  '33900',
#  '26900',
#  '119900',
#  '13900']

# %%
start = 1
title_list = []
url_list = []
# price_list = []

while start<37: #1페이지~36페이지
    try:
        url = 'https://www.musinsa.com/brands/musinsastandard?category3DepthCodes=&category2DepthCodes=&category1DepthCode=&colorCodes=&startPrice=&endPrice=&exclusiveYn=&includeSoldOut=&saleGoods=&timeSale=&includeKeywords=&sortCode=emt_high&tags=&page={}&size=90&listViewType=small&campaignCode=&groupSale=&outletGoods=false&boutiqueGoods='.format(start)
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'lxml')

        for soup in soup.find_all('a', attrs={'class':'img-block'}):
            title_list.append(soup['title'])
            url_list.append('https:' + soup['href'])

        start += 1

    except:
        print(start)
        break

# %%
df = pd.DataFrame({'상품명': title_list,
                   'url': url_list})
df.to_csv('무신사.csv', encoding = 'utf-8-sig')
